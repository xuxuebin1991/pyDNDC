# %% [markdown]
# # 一、DNDC模型参数
# DNDC需要输入的参数主要有：站点信息、气象、土壤、作物、耕作、施肥、有机物料添加、灌溉、淹水、覆膜、放牧等模块。
# ### 1、站点信息
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Site|`__Site_name`|站点名称|
# |Latitude|`__Latitude`|站点纬度坐标|
# |Simulated years|`__Simulated_years`|模拟年限|
# |Record daily results|`__Daily_record`|是否记录日数据（0：不记录，1：记录）|
# |-|`__Unit_system`|单位系统|
#
# 在站点信息中需要根据提供的数据修改：站点名称、纬度这两个参数，使用 `DNDFixer` 方法进行修改；模拟年限一般固定。
# ### 2、气象
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Climate data type|`__Climate_data_type`|气象数据的格式，共有7中（1-7数字表示）|
# |N concentration in rainfall|`__N_in_rainfall`|降水中N浓度（ppm 或 mg N/L）|
# |Air background NH3 concentration|`__Air_NH3_concentration`|大气背景的NH3浓度（ug N/m<sup>3</sup>）|
# |Air background CO2 concentration|`__Air_CO2_concentration`|大气背景的CO2浓度（ppm）|
# |Annual increase rate of air CO2 concentration|`__CO2_increase_rate `|大气CO2年增加速率（ppm/yr）|
# |Number of climate files|`__Climate_files`|气象数据的数量（每年一个文件，与模拟年限数字对应）|
# |-|`1  path1`|气象文件的编号和路径|
# |Climate file mode|`__Climate_file_mode`|气象文件的模式|
#
# 在气象数据中，需要修改的参数有：气象文件的编号和路径，使用 `DNDFixer` 方法进行修改。
# ### 3、土壤
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Land-use|`__Land_use_ID`|土壤利用类型（1-6，1：Upland crop field，2：Rice paddy field，3：Moist grassland/pasture，4：Dry grassland/pasture，5：Wetland，6：Woodland）|
# |Texture|`__Soil_texture_ID`|土壤质地（1-14，1：sand, 2：loamy sand, 3：sandy loam, 4：silt loam, 5：loam, 6：sandy clay loam, 7：silty clay loam, 8：clay loam, 9：sandy clay, 10：silty clay, 11：clay, and 12：organic soil.|
# |Bulk density|`__Bulk_density`|0-10 cm 土壤容重（g/cm<sup>3<sup>）|
# |Soil pH|`__pH`|0-10 cm 土壤pH|
# |Clay fraction|`__Clay_fraction`|黏粒含量（W/W）|
# |Field capacity|`__Field_capacity`|土壤田间持水量下的充水孔隙度，0-1，默认情况下根据土壤质地自动设置|
# |Wilting point|`__Wilting_point`|土壤萎蔫点下的充水孔隙度，0-1，默认情况下根据土壤质地自动设置|
# |Conductivity|`__Hydro_conductivity`|水文饱和电导率（m/hr），默认情况下根据土壤质地自动设置|
# |Porosity|`__Porosity`|土壤孔隙度，0-1，默认情况下根据土壤质地自动设置|
# |by-pass flow rate |`__Bypass_flow`|如果土壤有大孔隙（通常用于热带土壤），旁通流量可设置，0-1，默认为0|
# |Depth of water retension layer|`__Water_retension_layer_depth`|保水层深度（m），它可以由土壤压实(在密集放牧的牧场中常见)或粘土盘形成，默认情况下农田土壤不考虑，可设置为9.9|
# |SOC at top layer|`__Top_layer_SOC`|表层（0-5 cm）土壤有机碳含量（kg C/kg soil）|
# |Litter fraction|`__Litter_fraction`|掉落物库（0-1），输入 `SOC at top layer` 后自动赋值|
# |Humads fraction|`__Humads_fraction`|活性腐殖质库（0-1），输入 `SOC at top layer` 后自动赋值|
# |Humus fraction|`__Humus_fraction`|惰性腐殖质库（0-1），输入 `SOC at top layer` 后自动赋值|
# |Adjusted litter factor|`__Adjusted_litter_factor`|掉落物调节因子，默认 1|
# |Adjusted humads factor|`__Adjusted_humads_factor`|活性腐殖质调节因子，默认 1|
# |Adjusted humus factor|`__Adjusted_humus_factor`|惰性腐殖质调节因子，默认 1|
# |Humads C/N ratio|`__Humads_C/N`|活性腐殖质C/N比，默认 10|
# |Humus C/N ratio|`__Humus_C/N`|惰性腐殖质C/N比，默认 10|
# |_Black C C/N ratio|`__Black_C_C/N`|黑炭C/N比，默认 0|
# |Depth of topsoil with uniform SOC content|`__SOC_profile_A`|在此深度（m）之上，有机碳含量是均匀的，默认0.08 m|
# |SOC decrease rate below top soil|`__SOC_profile_B`|表层土壤以下有机碳含量下降的速度，数值越高，有机碳下降速率越快，小于1表示随着深度增加，有机质含量增加；默认为1.4|
# |Initial nitrate content|`__Initial_nitrate_ppm `|土壤初始硝态氮含量（ppm）|
# |Initial ammonium content|`__Initial_ammonium_ppm`|土壤初始铵态氮含量（ppm）|
# |Soil microbial index|`__Soil_microbial_index`|土壤有毒物质对土壤微生物活性影响的指数，默认为1|
# |Slope|`__Soil_slope`|土壤表面坡度的百分比，水平土的斜率为 0|
# |Lateral influx index|`__Lateral_influx_index`|不太明确什么意义，默认 1|
# |Watertable depth|`__Watertable_depth`|不太明确什么意义，默认 1|
# |Soil salinity|`__Soil_salinity`|土壤盐分指数，0-100，当该指数 > 0 时，土壤盐分会影响作物生长和土壤微生物活性|
# |SCS curve|`__SCS_curve_use`|水土保持 SCS (Service)曲线，默认为 0，不使用SCS曲线|
#
# 在土壤数据中，需要修改的参数有：Land-use, Texture, Bulk density, Soil pH, SOC at top soil，Initial nitrate and nitrate contents, 使用 `DNDFixer` 方法进行修改。
#
# 注意 Clay fraction, Field capacity, Wilting point, Conductivity, Porosity 参数根据 Texture 赋值，其关系如下：
# |Texture|Clay fraction|Field capacity|Wilting point|Conductivity|Porosity|
# |--------|-----------|----|--------|-----------|----|
# |(1) Sand|0.03|0.15|0.1|0.6336|0.395|
# |(2) Loamy Sand|0.06|0.25|0.13|0.5628|0.411|
# |(3) Sandy Loam|0.09|0.32|0.15|0.1248|0.435|
# |(4) Silt Loam|0.14|0.4|0.2|0.02592|0.485|
# |(5) Loam|0.19|0.49|0.22|0.02502|0.451|
# |(6) Sandy clay loam|0.27|0.52|0.24|0.02268|0.421|
# |(7) Silty clay loam|0.34|0.55|0.26|0.015|0.477|
# |(8) Clay loam|0.41|0.57|0.27|0.00882|0.476|
# |(9) Sandy clay|0.43|0.6|0.28|0.008|0.426|
# |(10) Silty clay|0.49|0.63|0.3|0.008|0.492|
# |(11) Clay|0.63|0.75|0.45|0.008|0.482|
# |(12) Organic soil|0.06|0.55|0.26|0.008|0.701|
#
# ### 4、作物
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Cropping systems|`Cropping_systems`|在总模拟年期间采用的种植系统的数目，这个数字应该与 `__Cropping_system` 数量对应|
# |Cropping system #|`__Cropping_system`|种植系统序号|
# |Total years|`__Total_years`|某种植序号下总的种植年限|
# |Years of a cycle|`__Years_of_a_cycle`|种植系统的循环年限，如单/双季稻种植系统循环年限为 1 年，稻麦轮作为2年，这个数字应该与 `____Year` 数量对应|
# |Year #|`____Year`|种植年的序号|
# |Crops|`____Crops`|作物的数量，如单季稻为 1，双季稻为 2，这个数字应该与 `______Crop#` 数量对应|
# |Crop #|`______Crop#`|作物的序号|
# |Crop type|`______Crop_ID`|作物类型，0-88，常见的为有 0：Fallow，1：Corn，2：Winter_wheat，3：Soybean，20：Paddy_rice|
# |Planting month|`______Planting_month`|种植月份|
# |Planting day|`______Planting_day`|种植天，某月份下的第多少天|
# |Harvest month|`______Harvest_month`|收获月份|
# |Harvest day|`______Harvest_day`|收获天，某月份下的第多少天|
# |Harvest year|`______Harvest_year`|收获年份，1：在本年收获，2：在下一年收获|
# |Residue left in field|`______Residue_left_in_field`|秸秆还田比例，0-1|
# |Maximum yield|`______Maximum_yield`|最大产量|
# |Leaf fraction|`______Leaf_fraction`|成熟期叶占总生物量的比例，0-1|
# |Stem fraction|`______Stem_fraction`|成熟期茎占总生物量的比例，0-1|
# |Root_fraction|`______Root_fraction`|成熟期根占总生物量的比例，0-1|
# |Grain fraction|`______Grain_fraction`|成熟期籽粒占总生物量的比例，0-1|
# |Leaf C/N|`______Leaf_C/N`|叶的 C/N 比|
# |Stem C/N|`______Stem_C/N`|茎的 C/N 比|
# |Root C/N|`______Root_C/N`|根的 C/N 比|
# |Grain C/N|`______Grain_C/N`|籽粒的 C/N 比|
# |Accumulative temperature|`______Accumulative_temperature`|作物积温，℃ * day|
# |Optimum temperature|`______Optimum_temperature`|作物最适生长温度，℃|
# |Water requirement|`______Water_requirement`|作物需水量，g water/g dry matter|
# |N fixation index|`______N_fixation_index`|作物固氮指数，crop N/N from soil，非豆科作物的默认值是 1，对于豆科作物，固氮指数等于(植株全氮含量)/(植株从土壤中吸收的氮)的比值|
# |Vascularity|`______Vascularity`|表示湿地植物维管性的分数，0-1，水稻是 1 |
# |If cover crop|`______If_cover_crop`|是否作物覆盖|
# |If perennial crop|`______If_perennial_crop`|是否为多年生作物|
# |If transplanted|`______If_transplanted`|是否移栽|
# |Tree maturity age|`______Tree_maturity_age`|默认 0|
# |Tree current age|`______Tree_current_age`|默认 0|
# |Tree max leaf|`______Tree_max_leaf`|默认 0|
# |Tree min leaf|`______Tree_min_leaf`|默认 0|
#
# 需要说明的是，作物模块的参数比较复杂，有多个层级，包括 `Cropping systems`, `Years of a cycle`, `Crops`。 `Cropping systems` 层级还要囊括耕作、施肥、有机物料添加、灌溉、淹水、覆膜、放牧等模块。
#
# ### 5、耕作
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Tillage applications|`____Till_applications`|耕作应用的次数|
# |Tillage month|`______Till_month`|耕作月份|
# |Tillage day|`______Till_day`|耕作天，某月份下的第多少天|
# |Tillage method|`______Till_method`|耕作方法， 1：no-till (i.e., only mulching) (0 cm), 2：ploughing slightly (5 cm), :3：ploughing with disk or chisel (10 cm), 4：ploughing with moldboard (20 cm), 5： deep ploughing (30cm)|
#
# ### 6、施肥
# 施肥有很多种方式，手动、自动、精准，当然也可以有换控释肥、消化抑制剂等方式
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Fertilizer applications|`____Fertilizer_applications`|施肥的次数|
# |Fertilizing #|`______Fertilizing#`|施肥操作序号|
# |Fertilizing month|`______Fertilizing_month`|施肥月份|
# |Fertilizing day|`______Fertilizing_day`|哪天施肥，某月份下的第多少天|
# |Fertilizing method|`______Fertilizing_method`|施肥方法，0：表层撒施，1：injection|
# |Fertilizing depth|`______Fertilizing_depth`|施肥深度（cm）|
# |Nitrate|`______Nitrate`|硝态氮施用量|
# |Ammonium_bicarbonate|`______Ammonium_bicarbonate`|碳铵施用量|
# |Urea|`______Urea`|尿素施用量|
# |Anhydrous_ammonia|`______Anhydrous_ammonia`|无水氨施用量|
# |Ammonium|`______Ammonium`|铵态氮施用量|
# |Sulphate|`______Sulphate`|硫施用量|
# |Phosphate|`______Phosphate`|磷施用量|
# |Slow release rate|`______Slow_release_rate`|缓释期，速效肥料为 1，换控释肥由传入的缓控释期确定|
# |Nitrification inhibitor efficiency|`______Nitrification_inhibitor_efficiency`|硝化抑制剂的效率，0-1，不用硝化抑制剂则为 0 |
# |Nitrification inhibitor duration|`______Nitrification_inhibitor_duration`|硝化抑制剂的有效期（天），不用则为 0 |
# |Urease inhibitor efficiency|`______Urease_inhibitor_efficiency`|脲酶抑制剂的效率，0-1，不用则为 0 |
# |Urease inhibitor duration|`______Urease_inhibitor_duration`|脲酶抑制剂的有效期（天），不用则为 0 |
# |Fertilization option|`____Fertilization_option`|默认 0，与 `____Fertilizer_applications` 一个层级|
#
# ### 7、有机物料添加
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Fertilizer applications|`____Fertilizer_applications`|施肥的次数|
# |Manure applications|`____Manure_applications` |有机物料添加次数，次数字应该等于有机物料添加序号的个数|
# |Manuring #|`______Manuring#` |有机物料添加操作序号|
# |Manuring month|`______Manuring_month`|有机物料添加月份|
# |Manuring day|`______Manuring_day`|有机物料添加天，某月下的第多少天|
# |Manure amount|`______Manure_amount`|有机物料添加量（kg C/ha）|
# |Manure C/N|`______Manure_C/N`|有机物料 C/N 比|
# |Manure type|`______Manure_type`|有机物料类型，1-10，1：农家肥，2：绿肥，3：秸秆，4：浆料动物粪便，5：堆肥，6：豆饼，7：人粪，8：家禽粪便，9：污泥，10：肉或血粉|
# |Manuring method|`______Manuring_method`|有机物料添加方法，0：Surface spread，1：Incroporation，2：Injection|
# |Manure depth|`______Manure_depth`|有机物料添加深度（cm）|
# |Manure Organic N|`______Manure_OrgN`|有机物料中有机氮的添加量（kg N/ha）|
# |Manure NH4|`______Manure_NH4 `|有机物料中铵态氮的添加量（kg N/ha）|
# |Manure NO3|`______Manure_NO3`|有机物料中硝态氮的添加量（kg N/ha）|
#
# ### 8、灌溉
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Irrigation applications|`____Irrigation_applications`|灌溉的次数，当灌溉方式为 1 时，此参数为 0，|
# |Irrigation control|`____Irrigation_control`|灌溉的方式，0：基于灌溉事件，1：基于灌溉指数；只有当此参数为 0 时，才声明后续的灌溉二级参数，如 `______Irri_month` 等|
# |Irrigation index|`____Irrigation_index`|灌溉指数，当基于事件（0），则灌溉指数为 0 |
# |Irrigation method|`____Irrigation_method`|灌溉方法，默认为 0 |
# |Irrigation #|`______Irrigation#`|灌溉操作的序号，只有当 `____Irrigation_control = 0` 才有此参数|
# |Irrigation month|`______Irri_month`|灌溉月份，只有当 `____Irrigation_control = 0` 才有此参数|
# |Irrigation applications|`______Irri_day`|灌溉天，某个月第多少天，只有当 `____Irrigation_control = 0` 才有此参数|
# |Irrigation applications|`______Water_amount`|灌溉量（cm），只有当 `____Irrigation_control = 0` 才有此参数|
# |Irrigation applications|`______Irri_method`|灌溉方法，0-3，0：Furrow，1：Sprinkler，2：Drip(0cm)，3：Drip(15cm)|
#
# ### 9、淹水
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Flood applications|`____Flood_applications`|淹水操作次数|
# |Flood control|`____Water_control` |淹水方法，0：schedule 或者 empirical，1：Rainfed，2：Observed water-table data|
# |Flood N content|`____Flood_water_N`|淹水中氮含量，为 Rainfed 和 Observed water-table data 情况下声明的|
# |Leak rate|`____Leak_rate`|淹水泄露率（mm/day）|
# |Water gather index|`____Water_gather_index` |雨水收集指数，当|
# |Watertable file|`____Watertable_file`|Observed water-table data 数据路径|
# |Empirical_para_1|`____Empirical_para_1`|经验参数灌溉-参数1|
# |Empirical_para_2|`____Empirical_para_2`|经验参数灌溉-参数2|
# |Empirical_para_3|`____Empirical_para_3` |经验参数灌溉-参数3|
# |Empirical_para_4|`____Empirical_para_4` |经验参数灌溉-参数4|
# |Empirical_para_5|`____Empirical_para_5`|经验参数灌溉-参数5|
# |Empirical_para_6|`____Empirical_para_6`|经验参数灌溉-参数6|
# |Flooding #|`______Flooding#`|淹水操作序号，与淹水操作次数对应|
# |Flood start month|`______Start_month`|淹水操作开始月份|
# |Flood start day`______Start_day`|淹水操作开始天|
# |Flood end month|`______End_month`|淹水操作结束月份|
# |Flood end day|`______End_day`|淹水操作结束天|
# |Flood Water N|`______Water_N`|淹水中氮含量|
# |Flood alter wet dry|`______Alter_wet_dry`|是否为干湿交替（-5~5cm），0：不干湿交替（连续 10 cm 淹水），1：干湿交替|
#
# ### 10、覆膜
# |参数名称|dnd文件中字符|解释|
# |--------|-----------|----|
# |Film applications|`____Film_applications`|覆膜操作次数|
# |Film applications|`____Method`|覆膜操作方法，0：温室，1：覆膜，2：不覆膜|
# |Film applications|`______Filming#` |覆膜操作序号，与覆膜操作次数对应|
# |Film applications|`______Start_month`|覆膜操作开始月份|
# |Film applications|`______Start_day`|覆膜操作开始天|
# |Film applications|`______End_month`|覆膜操作结束月份|
# |Film applications|`______End_day`|覆膜操作结束天|
# |Film applications|`______Cover_fraction`|覆膜系数，0-1|
#
# ### 11、放牧和割草
# 此部分农田系统不涉及，不介绍。

# %% [markdown]
# # 二、模块文件准备脚本
# 由于DNDC有不同的模块，因此要分模块准备数据，编写相应模块的数据准备脚本。
# ### 1、站点信息模块
# 站点信息模块的dnd文件形式如下图：
#
# ![image.png](attachment:image.png)
#
# 因此，我们编写了一个站点信息准备模块 `DNDCSiteInfo`。

# %%
import re

class DNDCSiteInfo:
    def __init__(self):
        # 定义站点文件格式和默认参数
        self.default_site_information = ['Site_infomation\n',
                                        '\n',
                                        '__Site_name                                                   site_name\n',
                                        '__Simulated_years                                                     0\n',
                                        '__Latitude                                                            0\n',
                                        '__Daily_record                                                        0\n',
                                        '__Unit_system                                                         0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n']
        # 定义输入参数格式和默认值
        self.default_parameters = {'Site_name': 'site_name',
                                   'Simulated_years': 0,
                                   'Latitude': 0,
                                   'Daily_record': 0, 
                                   'Unit_system': 0}
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 进行参数替换的函数
    def set_parameters(self, parameter_dict):
        modified_table = [] # 构造一个空list，用于存放修改后的数据
        
        # 对站点名称进行替换
        if  'Site_name' in parameter_dict.keys():
            char_pattern = re.compile(r'(__Site_name\s+)(\S+)$')
            self.table = [char_pattern.sub(r'\1{}'.format(parameter_dict['Site_name']), line) for line in self.default_site_information]
        else:
            self.table = self.default_site_information
        
        # 对参数进行逐行替换    
        for i in range(len(self.table)):
            modified_line = self.table[i]
            # 正则化表达式对输入的参数值进行修改，如果没输入则保留默认值
            for parameter_name, new_value in parameter_dict.items():
                pattern = re.compile(f'(__{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))   
            # 将字符串设置为两端对齐，中间空格填充        
            modified_line_align = self.custom_align(modified_line, 72)
            modified_table.append(modified_line_align)

        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在这个模块中，我们定义了默认的站点数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入字典可对相应的参数值进行修改，得到新的站点数据。
#
# 需要主要的是：站点名称不能有空格。
#
# 具体的使用方法如下：

# %%
# 首先创建一个站点修改的实例
site_modifier = DNDCSiteInfo()

# 我们看看需要输入哪些参数以及默认参数
default_parameters = site_modifier.get_default_parameters()
print(default_parameters)

# 使用这个实例修改多个站点参数
parameters_to_modify = {'Site_name': 'test', 'Simulated_years': 200, 'Latitude': 52.0}
modified_table = site_modifier.set_parameters(parameters_to_modify)
modified_table
# Out:
# {'Site_name': 'site_name', 'Simulated_years': 0, 'Latitude': 0, 'Daily_record': 0, 'Unit_system': 0}
# ['Site_infomation\n',
#  '\n',
#  '__Site_name                                                         test\n',
#  '__Simulated_years                                                    200\n',
#  '__Latitude                                                          52.0\n',
#  '__Daily_record                                                         0\n',
#  '__Unit_system                                                          0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n']

# %% [markdown]
# ### 2、气象模块
# 气象模块的dnd文件内容格式如下：
#
# ![image.png](attachment:image.png)
#
# 此模块主要有7个参数需要传入，分别为：气候数据类型、降水中氮含量、大气中 NH3 背景浓度、大气中CO2背景浓度、气象数据数量与路径、气象数据的模式、大气 CO2 增加速率。其中气候数据类型主要有以下几种：
#
# |序号|数据格式|
# |---|---|
# |0|Jday, MeanT, Prec|
# |1|Jday, MaxT, MinT, Prec|
# |2|Jday, MaxT, MinT, Prec, Radiation|
# |3|Jday, MaxT, MinT, Prec, WindSpeed|
# |4|Jday, MaxT, MinT, Prec, Humidity|
# |5|Jday, MaxT, MinT, Prec, WindSpeed, Radiation, Humidity|
# |6|Jday, MaxT, MinT, Prec, WindSpeed, Humidity|
#
# 气象数据的数量与路径要对应。
#
# 基于此编写了一个气象数据准备模块 `DNDCWeather`。

# %%
import re

class DNDCWeather:
    def __init__(self):
        # 定义默认的参数
        self.default_weather_information = ['Climate_data\n',                            
                                            '\n',
                                            '__Climate_data_type                                                   1\n',
                                            '__N_in_rainfall                                                       0\n',
                                            '__Air_NH3_concentration                                          0.0600\n',
                                            '__Air_CO2_concentration                                        420.0000\n',
                                            '__Climate_files                                                       1\n',
                                            '1                                                                 path1\n',
                                            '__Climate_file_mode                                                   0\n',
                                            '__CO2_increase_rate                                              0.0000\n',
                                            '__None                                                                0\n',
                                            '__None                                                                0\n',
                                            '__None                                                                0\n',
                                            '__None                                                                0\n',
                                            '__None                                                                0\n']
        # 定义输入参数格式和默认值 
        self.default_parameters = {'Climate_data_type': 1,
                                   'N_in_rainfall': 0,
                                   'Air_NH3_concentration': 0.06,
                                   'Air_CO2_concentration': 420, 
                                   'Climate_file_mode': 0,
                                   'CO2_increase_rate': 0
                                   }
    
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 进行参数替换的函数
    def set_parameters(self, parameter_dict, path_list):
        modified_table = []
        path_number = 1
        add_paths = False  # 跟踪何时添加路径的标志

        # # 对站点名称进行替换
        for i in range(len(self.default_weather_information)):
            modified_line = self.default_weather_information[i]

            # 检查行是否包含 '__Climate_files'
            if '__Climate_files' in modified_line:
                add_paths = True # 当含'__Climate_files'时将跟踪参数设置为True
                # 跳过现有的路径
                while '__Climate_files' not in modified_line:
                    modified_line = self.default_weather_information[i]
                    i += 1

                # 根据输入路径更新路径数
                modified_line = f'__Climate_files                                                       {len(path_list)}\n'

            # 检查行是否包含 '__Climate_file_mode'
            if '__Climate_file_mode' in modified_line:
                add_paths = False # 当含'__Climate_file_mode'时将跟踪参数设置为True
                # 添加带有编号的路径，在'__Climate_files'和'__Climate_file_mode'之间
                for path in path_list:
                    modified_table.append(f"{path_number}                                                                 {path}\n")
                    path_number += 1

            # 跳过现有路径
            if add_paths and modified_line.strip() and not modified_line.startswith('__'):
                continue

            # 对参数进行逐行替换 
            for parameter_name, new_value in parameter_dict.items():
                pattern = re.compile(f'(__{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))

            modified_line_align = self.custom_align(modified_line, 72) 
            modified_table.append(modified_line_align)

        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在这个模块中，我们定义了默认的气象数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入参数字典和路径列表，可对相应的参数值和气象数据的路径进行修改，得到新的气象文件。
#
# 需要注意：
#
# （1）`Climate_data_type` 表示气候数据的类型，主要有：
#
# |序号|数据格式|
# |---|---|
# |0|Jday, MeanT, Prec|
# |1|Jday, MaxT, MinT, Prec|
# |2|Jday, MaxT, MinT, Prec, Radiation|
# |3|Jday, MaxT, MinT, Prec, WindSpeed|
# |4|Jday, MaxT, MinT, Prec, Humidity|
# |5|Jday, MaxT, MinT, Prec, WindSpeed, Radiation, Humidity|
# |6|Jday, MaxT, MinT, Prec, WindSpeed, Humidity|
#
# 单位分别为：Prec(cm)，Radiation(MJ/m2/day), WindSpeed(m/s), Humidity(%rh)
#
# （2）需要通过列表传入气候文件，`Climate_files` 值会自动根据传入的文件数量进行自动识别；
#
# （3）`Climate_file_mode` 只有 0 和 1, 0 每年都有自己的气候文件，1 表示使用 1 个气候文件代表所有模拟年。

# %%
# 实例化一个气象模块修改方法
weather_modifier = DNDCWeather()

# 查看需要输入的参数
default_parameters = weather_modifier.get_default_parameters()
print(default_parameters)

# 设置参数并添加路径
parameters = {'Climate_data_type': 2, 'N_in_rainfall': 3.0000, 'Air_NH3_concentration': 1.2000}
paths = ['path2', 'path3'] # 添加气象数据的绝对路径
modified_table = weather_modifier.set_parameters(parameters, paths)
modified_table
# Out:
# {'Climate_data_type': 1, 'N_in_rainfall': 0, 'Air_NH3_concentration': 0.06, 'Air_CO2_concentration': 420, 'Climate_file_mode': 0, 'CO2_increase_rate': 0}
# ['Climate_data\n',
#  '\n',
#  '__Climate_data_type                                                    2\n',
#  '__N_in_rainfall                                                      3.0\n',
#  '__Air_NH3_concentration                                              1.2\n',
#  '__Air_CO2_concentration                                         420.0000\n',
#  '__Climate_files                                                        2\n',
#  '1                                                                 path2\n',
#  '2                                                                 path3\n',
#  '__Climate_file_mode                                                    0\n',
#  '__CO2_increase_rate                                               0.0000\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n']

# %% [markdown]
# ### 3、土壤模块
# 土壤模块的dnd文件参数比较多，如下所示：
#
# ![image.png](attachment:image.png)
#
# 因此，我们编写了一个土壤信息准备模块 `DNDCSoil`。

# %%
import re

class DNDCSoil:
    #
    def __init__(self):
        # 定义土壤文件格式和默认参数
        self.default_soil_information = ['Soil_data\n',
                                        '\n',
                                        '__Land_use_ID                                                         1\n',
                                        '__Soil_texture_ID                                                     1\n',
                                        '__Bulk_density                                                   1.0000\n',
                                        '__pH                                                             7.0000\n',
                                        '__Clay_fraction                                                  0.0300\n',
                                        '__Porosity                                                       0.3950\n',
                                        '__Bypass_flow                                                    0.0000\n',
                                        '__Field_capacity                                                 0.1500\n',
                                        '__Wilting_point                                                  0.1000\n',
                                        '__Hydro_conductivity                                             0.6336\n',
                                        '__Top_layer_SOC                                                  0.0100\n',
                                        '__Litter_fraction                                                0.0100\n',
                                        '__Humads_fraction                                                0.0184\n',
                                        '__Humus_fraction                                                 0.9716\n',
                                        '__Adjusted_litter_factor                                         1.0000\n',
                                        '__Adjusted_humads_factor                                         1.0000\n',
                                        '__Adjusted_humus_factor                                          1.0000\n',
                                        '__Humads_C/N                                                    10.0000\n',
                                        '__Humus_C/N                                                     10.0000\n',
                                        '__Black_C                                                        0.0000\n',
                                        '__Black_C_C/N                                                  500.0000\n',
                                        '__SOC_profile_A                                                  0.0800\n',
                                        '__SOC_profile_B                                                  1.4000\n',
                                        '__Initial_nitrate_ppm                                            0.5000\n',
                                        '__Initial_ammonium_ppm                                           0.0500\n',
                                        '__Soil_microbial_index                                           1.0000\n',
                                        '__Soil_slope                                                     0.0000\n',
                                        '__Lateral_influx_index                                           1.0000\n',
                                        '__Watertable_depth                                               1.0000\n',
                                        '__Water_retension_layer_depth                                    9.9900\n',
                                        '__Soil_salinity                                                  0.0000\n',
                                        '__SCS_curve_use                                                       0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n',
                                        '__None                                                                0\n']
        # 定义部分输入参数格式和默认值
        self.default_parameters = {'Land_use_ID': 0, 
                                   'Soil_texture_ID': 1,
                                   'Bulk_density': 1,
                                   'pH': 7,
                                   'Top_layer_SOC': 0.01,
                                   'Initial_nitrate_ppm': 0.5000,
                                   'Initial_ammonium_ppm': 0.0500,
                                    'Soil_microbial_index': 1,
                                    'Soil_slope': 0,
                                    'Water_retension_layer_depth': 9.99,
                                    'Soil_salinity': 0}

        self.table = self.default_soil_information
        
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 进行参数替换的函数 
    def set_parameters(self, parameter_dict=None):
        # 检测是否输入参数，否则报错
        if parameter_dict is None:
            raise ValueError("Please provide a parameter dictionary.")
        
        # 检查是否输入土地利用方式，否则报错
        if 'Land_use_ID' not in parameter_dict:
            raise ValueError("Please define 'Land_use_ID' in the parameter dictionary.")

        # 检查是否输入土壤质地，否则报错
        if 'Soil_texture_ID' not in parameter_dict:
            raise ValueError("Please define 'Soil_texture_ID' in the parameter dictionary.")

        # 使用预定义的土壤参数映射土壤质地
        soil_texture_id = parameter_dict['Soil_texture_ID']
        texture_mapping = self.get_parameters_from_texture(soil_texture_id)
        
        for param_name_texture, param_value_texture in texture_mapping.items():
            if param_name_texture not in parameter_dict.keys():
                parameter_dict[param_name_texture] = param_value_texture
       
        # 检查是否输入土壤有机质含量，否则报错
        if 'Top_layer_SOC' not in parameter_dict:
            raise ValueError("Please define 'Top_layer_SOC' in the parameter dictionary.")
        
        # 使用默认soc的预定义映射对 'Litter_fraction', 'Humads_fraction', 'Humus_fraction'参数赋值
        params_fraction = ['Litter_fraction', 'Humads_fraction', 'Humus_fraction']
        if not all(param in parameter_dict for param in params_fraction):
            print('The input parameters of soc fraction is insufficient, using defaut values !')
            soc_content = parameter_dict['Top_layer_SOC']
            soc_mapping = self.get_parameters_from_soc(soc_content)     
            parameter_dict.update(soc_mapping)       
        else:
            if  sum([parameter_dict[key] for key in params_fraction]) != 1:
                raise ValueError("The total fraction is not 1, please ensure the total fraction is 1")
        
        modified_table = []           
        # 对参数进行逐行替换
        for i in range(len(self.table)):
            modified_line = self.table[i]

            for parameter_name, new_value in parameter_dict.items():
                pattern = re.compile(f'(__{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            
            modified_line_align = self.custom_align(modified_line, 72) # 将字符串设置为两端对齐，中间空格填充
            modified_table.append(modified_line_align)

        return modified_table
    
    # 用于土壤质地映射的函数
    def get_parameters_from_texture(self, soil_texture_id):
        # 土壤质地映射表
        texture_mapping = {
            1: {'Clay_fraction': 0.0300, 'Field_capacity': 0.1500, 'Wilting_point': 0.1000, 'Hydro_conductivity': 0.6336, 'Porosity': 0.3950},
            2: {'Clay_fraction': 0.0600, 'Field_capacity': 0.2500, 'Wilting_point': 0.1300, 'Hydro_conductivity': 0.5628, 'Porosity': 0.4110},
            3: {'Clay_fraction': 0.0900, 'Field_capacity': 0.3200, 'Wilting_point': 0.1500, 'Hydro_conductivity': 0.1248, 'Porosity': 0.4350},
            4: {'Clay_fraction': 0.1400, 'Field_capacity': 0.400, 'Wilting_point': 0.2000, 'Hydro_conductivity': 0.02592, 'Porosity': 0.4850},
            5: {'Clay_fraction': 0.1900, 'Field_capacity': 0.4900, 'Wilting_point': 0.2200, 'Hydro_conductivity': 0.02502, 'Porosity': 0.4510},
            6: {'Clay_fraction': 0.2700, 'Field_capacity': 0.5200, 'Wilting_point': 0.2400, 'Hydro_conductivity': 0.02268, 'Porosity': 0.4210},
            7: {'Clay_fraction': 0.3400, 'Field_capacity': 0.5500, 'Wilting_point': 0.2600, 'Hydro_conductivity': 0.0150, 'Porosity': 0.4770},
            8: {'Clay_fraction': 0.4100, 'Field_capacity': 0.5700, 'Wilting_point': 0.2700, 'Hydro_conductivity': 0.00882, 'Porosity': 0.4760},
            9: {'Clay_fraction': 0.4300, 'Field_capacity': 0.6000, 'Wilting_point': 0.2800, 'Hydro_conductivity': 0.0080, 'Porosity': 0.4260},
            10: {'Clay_fraction': 0.4900, 'Field_capacity': 0.6300, 'Wilting_point': 0.3000, 'Hydro_conductivity': 0.0080, 'Porosity': 0.4920},
            11: {'Clay_fraction': 0.6300, 'Field_capacity': 0.7500, 'Wilting_point': 0.4500, 'Hydro_conductivity': 0.0080, 'Porosity': 0.4820},
            12: {'Clay_fraction': 0.0600, 'Field_capacity': 0.5500, 'Wilting_point': 0.2600, 'Hydro_conductivity': 0.0080, 'Porosity': 0.7010}
        }
        return texture_mapping.get(soil_texture_id, {})
    
    # 用于土壤有机质组分映射的函数
    def get_parameters_from_soc(self, soc_content):
        # 默认的土壤有机质组分映射表
        litter_fraction = 0.01           
        humads_fraction = 0.4611 * soc_content + 0.0138
        humus_fraction = 1 - litter_fraction - humads_fraction
        soc_mapping = {
            'Litter_fraction': litter_fraction,
            'Humads_fraction': humads_fraction,
            'Humus_fraction': humus_fraction
        }
        return soc_mapping
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在这个模块中，我们定义了默认的土壤数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入参数字典列表，可对相应的土壤参数进行修改，得到新的土壤文件。具体的使用方法如下：
#
# 值得注意的是：
#
# （1）当只传入 `Soil_texture` 时，土壤性质参数 `Clay_fraction`，`Field_capacity`，`Wilting_point`，`Hydro_conductivity`，`Porosity` 参数值根据土壤质地 `Soil_texture` 设定为默认值；
#
# （2）当既传入 `Soil_texture` 又传入部分土壤性质参数（ `Clay_fraction`，`Field_capacity`，`Wilting_point`，`Hydro_conductivity`，`Porosity` ）时，只对自定义传入的参数进行修改，其他未传入的参数根据土壤质地 `Soil_texture` 设定为默认值；
#
# （3）如果要定义 SOC 分组情况，必须要同时传入 `Humads_fraction`, `Humads_fraction`, `Humus_fraction` 这三个参数，否则将 SOC 分组设置为默认情形（即 `Litter_fraction` = 0.01，`Humads_fraction` 和`Humus_fraction` 根据传入的 `Top_layer_SOC` 值确定；计算公式为：`Humads_fraction` =  `Top_layer_SOC` * 0.4611 + 0.0138，`Humus_fraction` = 1 - `Humads_fraction` - `Humads_fraction`；
#
# （4）收到传入的 `Humads_fraction`, `Humads_fraction`, `Humus_fraction` 三个参数之和要等于 1，否则报错；
#
# （5）`Land_use_ID`, `Soil_texture_ID`, `Top_layer_SOC` 为必须要传入的参数，否则报错；
#
# （6）`Top_layer_SOC` 的单位为 kgC/kg soil，0-10 cm 土层。

# %%
# 首先实例化模块
soil_modifier = DNDCSoil()

# 查看默认参数
default_parameters = soil_modifier.get_default_parameters()
print(default_parameters)

# 只传入Soil_texture；Clay_fraction，Field_capacity，Wilting_point，Hydro_conductivity，Porosity参数值由Soil_texture确定
# 传入自定义的Clay_fraction，Field_capacity，Wilting_point，Hydro_conductivity，Porosity参数值，可对传入的参数值进行部分修改
parameter_dict = {'Land_use_ID': 20, 'Soil_texture_ID':10, 'Clay_fraction': 0.02, 'Litter_fraction': 0.02, 'Humads_fraction': 0.05, 'Humus_fraction': 0.93, 'Top_layer_SOC': 0.1}
modified_soil = soil_modifier.set_parameters(parameter_dict)
modified_soil
# Out:
# {'Land_use_ID': 0, 'Soil_texture_ID': 1, 'Bulk_density': 1, 'pH': 7, 'Top_layer_SOC': 0.01, 'Initial_nitrate_ppm': 0.5, 'Initial_ammonium_ppm': 0.05, 'Soil_microbial_index': 1, 'Soil_slope': 0, 'Water_retension_layer_depth': 9.99, 'Soil_salinity': 0}
# ['Soil_data\n',
#  '\n',
#  '__Land_use_ID                                                         20\n',
#  '__Soil_texture_ID                                                     10\n',
#  '__Bulk_density                                                    1.0000\n',
#  '__pH                                                              7.0000\n',
#  '__Clay_fraction                                                     0.02\n',
#  '__Porosity                                                         0.492\n',
#  '__Bypass_flow                                                     0.0000\n',
#  '__Field_capacity                                                    0.63\n',
#  '__Wilting_point                                                      0.3\n',
#  '__Hydro_conductivity                                               0.008\n',
#  '__Top_layer_SOC                                                      0.1\n',
#  '__Litter_fraction                                                   0.02\n',
#  '__Humads_fraction                                                   0.05\n',
#  '__Humus_fraction                                                    0.93\n',
#  '__Adjusted_litter_factor                                          1.0000\n',
#  '__Adjusted_humads_factor                                          1.0000\n',
#  '__Adjusted_humus_factor                                           1.0000\n',
#  '__Humads_C/N                                                     10.0000\n',
#  '__Humus_C/N                                                      10.0000\n',
#  '__Black_C                                                         0.0000\n',
#  '__Black_C_C/N                                                   500.0000\n',
#  '__SOC_profile_A                                                   0.0800\n',
#  '__SOC_profile_B                                                   1.4000\n',
#  '__Initial_nitrate_ppm                                             0.5000\n',
#  '__Initial_ammonium_ppm                                            0.0500\n',
#  '__Soil_microbial_index                                            1.0000\n',
#  '__Soil_slope                                                      0.0000\n',
#  '__Lateral_influx_index                                            1.0000\n',
#  '__Watertable_depth                                                1.0000\n',
#  '__Water_retension_layer_depth                                     9.9900\n',
#  '__Soil_salinity                                                   0.0000\n',
#  '__SCS_curve_use                                                        0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n',
#  '__None                                                                 0\n']

# %% [markdown]
# ### 4、耕作模块
# 在 DNDC 模型中，耕作（Cropping）模块的格式比较复杂，Crop、Tillage、Fertilization、Manure Amendment、Irrigation、Flooding、Film mulch、Grazing or cutting 这几个模块都集成到 Cropping 模块中，所以 Cropping 模块的子层级比较多。Cropping 模块的 dnd 文件格式如下：
#
# ![image.png](attachment:image.png)
#
# 此外，由于在每个子模块中有不同的作物/管理事件，每个子模块中可能也有不同的子事件。因此，层级非常多。需要考虑的有：
# （1）总共需要模拟多少年，这个要与之前站点模块的年份对应；
# （2）在模拟年份中，总共有多少耕作系统，如：稻-稻、稻-麦、稻-油等；
# （3）每个耕作系统分别持续多少年，所有耕作系统的持续年份加起来应该等于总共模拟的年数；
# （4）每个耕作系统一个循环需要多少年，比如稻-稻轮作一个循环需要 1 年、稻-麦和稻-油轮作一个循环需要 2 年；
# （5）在每个耕作循环中，都有哪些耕作管理措施，比如在每个稻-麦轮作循环中，一个循环需要 2 年，在这个循环中需要施肥、施有机肥、灌溉、淹水等管理措施，稻季的管理措施一般在第一年，而麦季的部分管理措施在第一年，部分则在第二年。
#
# 这里举个例子：假如我们模拟 100 年，在这 100 年间前 30 年为稻-麦轮作，后 70 年为稻-稻轮作，则该种植模式的布局如下：
# - 总模拟年（100 年）：
#     - 总的耕作系统（2，稻-麦、稻-稻）：
#         - 第 1 个耕作系统的年限（30 年，稻-麦）：
#            - 第 1 个耕作系统的循环周期（2 年）：
#                 - 第 1 年的作物：
#                     - 水稻
#                     - 小麦
#                 - 第 2 年的作物
#                     - 小麦
#         - 第 2 个耕作系统的年限（70 年，稻-稻）：
#             - 第 1 个耕作系统的循环周期（1 年）：
#                 - 第 1 年的作物：
#                     - 水稻
#                     - 水稻
#
# 因此，为了方便起见，我们首先要从子层级的模块展开定义。
# #### 4.1 作物模块
# 作物模块 dnd 文件内容如下图所示：
#
# ![image-2.png](attachment:image-2.png)
#
# 因此相应的修改模块 `DNDCCrop` 定义如下：

# %%
import re

class DNDCCrop:
    # 定义作物文件格式和默认参数
    def __init__(self):
        self.crop_number = ['____Crops                                                             1\n']
        self.default_crop_information = ['______Crop#                                                           1\n',
                                        '______Crop_ID                                                        20\n',
                                        '______Planting_month                                                  4\n',
                                        '______Planting_day                                                    1\n',
                                        '______Harvest_month                                                   6\n',
                                        '______Harvest_day                                                    30\n',
                                        '______Harvest_year                                                    1\n',
                                        '______Residue_left_in_field                                      0.0000\n',
                                        '______Maximum_yield                                           3377.5801\n',
                                        '______Leaf_fraction                                              0.2300\n',
                                        '______Stem_fraction                                              0.2400\n',
                                        '______Root_fraction                                              0.1200\n',
                                        '______Grain_fraction                                             0.4100\n',
                                        '______Leaf_C/N                                                  85.0000\n',
                                        '______Stem_C/N                                                  85.0000\n',
                                        '______Root_C/N                                                  85.0000\n',
                                        '______Grain_C/N                                                 45.0000\n',
                                        '______Accumulative_temperature                                2000.0000\n',
                                        '______Optimum_temperature                                       25.0000\n',
                                        '______Water_requirement                                        508.0000\n',
                                        '______N_fixation_index                                           1.0500\n',
                                        '______Vascularity                                                1.0000\n',
                                        '______If_cover_crop                                                   0\n',
                                        '______If_perennial_crop                                               0\n',
                                        '______If_transplanted                                                 1\n',
                                        '______Tree_maturity_age                                 -107374000.0000\n',
                                        '______Tree_current_age                                           0.0000\n',
                                        '______Tree_max_leaf                                              0.0000\n',
                                        '______Tree_min_leaf                                              0.0000\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '______None                                                            0\n',
                                        '\n']
        # 定义默认的作物参数
        self.default_crop = {0:{'Maximum_yield': 0,
                                'Leaf_fraction': 0.25,
                                'Stem_fraction': 0.25,
                                'Root_fraction': 0.4,
                                'Grain_fraction': 0.1,
                                'Leaf_C/N': 1,
                                'Stem_C/N': 1,
                                'Root_C/N': 1,
                                'Grain_C/N': 1,
                                'Accumulative_temperature': 0,
                                'Optimum_temperature': 20,
                                'Water_requirement': 0,
                                'N_fixation_index': 1,
                                'Vascularity': 0},
                            1: {'Maximum_yield': 4123.6,
                                'Leaf_fraction': 0.22,
                                'Stem_fraction': 0.22,
                                'Root_fraction': 0.16,
                                'Grain_fraction': 0.4,
                                'Leaf_C/N': 80,
                                'Stem_C/N': 80,
                                'Root_C/N': 80,
                                'Grain_C/N': 50,
                                'Accumulative_temperature': 2550.0000,
                                'Optimum_temperature': 30.0000,
                                'Water_requirement': 150.0000,
                                'N_fixation_index': 1.0000,
                                'Vascularity': 0},
                            2: {'Maximum_yield': 3120.1,
                                'Leaf_fraction': 0.21,
                                'Stem_fraction': 0.21,
                                'Root_fraction': 0.17,
                                'Grain_fraction': 0.41,
                                'Leaf_C/N': 95,
                                'Stem_C/N': 95,
                                'Root_C/N': 95,
                                'Grain_C/N': 40,
                                'Accumulative_temperature': 1300.0000,
                                'Optimum_temperature': 22.0000,
                                'Water_requirement': 200.0000,
                                'N_fixation_index': 1.0000,
                                'Vascularity': 0},
                            20: {'Maximum_yield': 3377.58,
                                'Leaf_fraction': 0.23,
                                'Stem_fraction': 0.24,
                                'Root_fraction': 0.12,
                                'Grain_fraction': 0.41,
                                'Leaf_C/N': 85,
                                'Stem_C/N': 85,
                                'Root_C/N': 85,
                                'Grain_C/N': 45,
                                'Accumulative_temperature': 2000.0000,
                                'Optimum_temperature': 25.0000,
                                'Water_requirement': 2000.0000,
                                'N_fixation_index': 1.0500,
                                'Vascularity': 1},
                            }
        
        # 定义输入参数格式和默认值
        self.default_parameters = {1: {'Planting_month': 1,
                                   'Planting_day': 1,
                                   'Harvest_month': 1,
                                   'Harvest_day': 1, 
                                   'Harvest_year': 0,
                                   'Residue_left_in_field': 1,
                                   'Maximum_yield': '-',
                                   'If_cover_crop': 0,
                                   'If_perennial_crop': 0, 
                                   'If_transplanted': 1,
                                   }}
        
        self.table = self.default_crop_information
    
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 进行参数替换的函数 
    def set_parameters(self, parameter_dict=None):
        # 检查是否输入参数
        if parameter_dict is None:
            raise ValueError("Please provide a parameter dictionary.")              
 
        modified_list = []
        times= len(parameter_dict)
        modified_crop_number = [line.replace('1', str(times)) for line in self.crop_number]
        for crop_num, sub_parameters_dict in parameter_dict.items():
            # 检查Crop_ID是否输入
            if 'Crop_ID' not in sub_parameters_dict:
                raise ValueError("Please define 'Crop_ID' in the parameter dictionary.")

            # 检查输入作物的参数是否在默认数据中，如果没有则用户需要手动添加
            if sub_parameters_dict['Crop_ID'] not in self.default_crop.keys():
                raise ValueError("There is no defaut values for your crop, please define crop parameters. Your can refer to  http://www.dndc.sr.unh.edu/model/GuideDNDC95.pdf")
            
            # 为输入的作为设置默认的作物参数
            crop_id = sub_parameters_dict['Crop_ID']
            crop_mapping = self.default_crop.get(crop_id, {})
            for param_name, param_value in crop_mapping.items():
                if param_name not in parameter_dict.keys():
                    sub_parameters_dict[param_name] = param_value    
            
            first_string = self.table[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(crop_num), first_string, count=1)
            modified_table = self.modify(self.table[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        modified = modified_crop_number + modified_list
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
   
        # 定义一个修改参数的函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_table.append(modified_line)
        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在作物模块中，我们定义了默认的作物数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入参数字典列表，可对相应的作物参数进行修改，得到新的作物文件。我们还内置了三个默认的作物参数：休耕（0），玉米（1）,冬小麦（2），水稻（20）；对于其他作物，可以参考 http://www.dndc.sr.unh.edu/model/GuideDNDC95.pdf 教程，对作物参数进行修改。具体的使用方法如下：
#
# 注意：
# （1）`Harvest_year` 表示在哪一年收获，1-表示种植年收获，2-表示下一年收获；

# %%
# 首先实例化模块
crop_modifier = DNDCCrop()

# 查看默认的参数
print(crop_modifier.get_default_parameters())

# 构建一个水稻，水稻的参数使用默认参数，产量自己定义
parameter_dict = {1: {'Crop_ID': 20, 
                  'Planting_month': 4, 'Planting_day': 1, 'Harvest_month': 7, 'Harvest_day': 20, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 4000
                  }}
modified_crop = crop_modifier.set_parameters(parameter_dict)
modified_crop
# Out:
# {1: {'Planting_month': 1, 'Planting_day': 1, 'Harvest_month': 1, 'Harvest_day': 1, 'Harvest_year': 0, 'Residue_left_in_field': 1, 'Maximum_yield': '-', 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1}}
# ['____Crops                                                              1\n',
#  '______Crop#                                                            1\n',
#  '______Crop_ID                                                         20\n',
#  '______Planting_month                                                   4\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                    7\n',
#  '______Harvest_day                                                     20\n',
#  '______Harvest_year                                                     1\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                              3377.58\n',
#  '______Leaf_fraction                                                 0.23\n',
#  '______Stem_fraction                                                 0.24\n',
#  '______Root_fraction                                                 0.12\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        85\n',
#  '______Stem_C/N                                                        85\n',
#  '______Root_C/N                                                        85\n',
#  '______Grain_C/N                                                       45\n',
#  '______Accumulative_temperature                                    2000.0\n',
#  '______Optimum_temperature                                           25.0\n',
#  '______Water_requirement                                           2000.0\n',
#  '______N_fixation_index                                              1.05\n',
#  '______Vascularity                                                      1\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  1\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n']

# %% [markdown]
# #### 4.2 耕作模块
# 耕作模块比较简单，dnd 文件内容如下图所示：
#
# ![image.png](attachment:image.png)
#
# 因此，写一个 `DNDCTillage` 模块。

# %%
import re

class DNDCTillage:
    # 定义站点文件格式和默认参数
    def __init__(self):   
        self.default_tillage_applications = ['____Till_applications                                                 1\n']
        self.default_tillage_informations = ['______Till#                                                           1\n',
                                        '______Till_month                                                      1\n',
                                        '______Till_day                                                        1\n',
                                        '______Till_method                                                     1\n']
        
        self.default_parameters = {1: {'Till_month': 1,
                                        'Till_day': 1,
                                        'Till_method': 1}}

        self.tillage_applications = self.default_tillage_applications
        self.tillage_informations = self.default_tillage_informations
    
    # 进行参数替换的函数
    def set_parameters(self, parameter_dict):
        modified_list = []
        times= len(parameter_dict)
        modified_tillage_application = [line.replace('1', str(times)) for line in self.tillage_applications]
        for tillage_times, sub_parameters_dict in parameter_dict.items():
            first_string = self.default_tillage_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(tillage_times), first_string, count=1)
            modified_table = self.modify(self.default_tillage_informations[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        modified = modified_tillage_application + modified_list
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义一个修改参数的函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_table.append(modified_line)
        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在耕作模块中，我们定义了默认的耕作数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入参数字典列表，可对相应的耕作参数进行修改，得到新的耕作文件。
#
# 注意：Till_method 主要有：
#
# ![image.png](attachment:image.png)

# %%
# 实例化一个
tillage_modifier = DNDCTillage()
parameter_dict = {1: {'Till_month': 5, 'Till_day': 15, 'Till_method': 2},
                  2: {'Till_month': 7, 'Till_day': 20, 'Till_method': 3},
                  3: {'Till_month': 9, 'Till_day': 20, 'Till_method': 0}}
modifier_tillage = tillage_modifier.set_parameters(parameter_dict)
modifier_tillage
# Out:
# ['____Till_applications                                                  3\n',
#  '______Till#                                                            1\n',
#  '______Till_month                                                       5\n',
#  '______Till_day                                                        15\n',
#  '______Till_method                                                      2\n',
#  '______Till#                                                            2\n',
#  '______Till_month                                                       7\n',
#  '______Till_day                                                        20\n',
#  '______Till_method                                                      3\n',
#  '______Till#                                                            3\n',
#  '______Till_month                                                       9\n',
#  '______Till_day                                                        20\n',
#  '______Till_method                                                      0\n']

# %% [markdown]
# #### 4.3 施肥模块
# 施肥模块 dnd 文件内容有四种情况，如下：
#
# （1）手动施肥：事件施肥
#
# ![image.png](attachment:image.png)
#
# （2）自动施肥：尿素根据作物对养分的需求供给养分
#
# ![image-2.png](attachment:image-2.png)
#
# （3）精准施肥：只要作物受养分胁迫，就供给尿素
#
# ![image-3.png](attachment:image-3.png)
#
# （4）根据施肥文件
#
# ![image-4.png](attachment:image-4.png)
#
# 基于此，编写 `DNDCFertilizer` 模块。

# %%
import re

class DNDCFertilizer:
    # 定义施肥文件格式和默认参数
    def __init__(self):
        self.default_manual_fertilization_application = ['____Fertilizer_applications                                           1\n']
        self.default_manual_fertilization_informations = ['______Fertilizing#                                                    1\n',
                                                         '______Fertilizing_month                                               1\n',
                                                         '______Fertilizing_day                                                 1\n',
                                                         '______Fertilizing_method                                              0\n',
                                                         '______Fertilizing_depth                                          0.0000\n',
                                                         '______Nitrate                                                    0.0000\n',
                                                         '______Ammonium_bicarbonate                                       0.0000\n',
                                                         '______Urea                                                       0.0000\n',
                                                         '______Anhydrous_ammonia                                          0.0000\n',
                                                         '______Ammonium                                                   0.0000\n',
                                                         '______Sulphate                                                   0.0000\n',
                                                         '______Phosphate                                                  0.0000\n',
                                                         '______Slow_release_rate                                          1.0000\n',
                                                         '______Nitrification_inhibitor_efficiency                         0.0000\n',
                                                         '______Nitrification_inhibitor_duration                           0.0000\n',
                                                         '______Urease_inhibitor_efficiency                                0.0000\n',
                                                         '______Urease_inhibitor_duration                                  0.0000\n',
                                                         '______None                                                            0\n',
                                                         '______None                                                            0\n',
                                                         '______None                                                            0\n',
                                                         '______None                                                            0\n',
                                                         '______None                                                            0\n']
        self.auto_fertilization = ['____Fertilizer_applications                                          -2\n',
                                   '____Fertilization_option                                              0\n']
        self.precision_fertilization = ['____Fertilizer_applications                                          -3\n',
                                        '____Fertilization_option                                              0\n']
        self.fertig_fertilization = ['____Fertilizer_applications                                          -1\n',
                                     '______Fertilization_file                                           path\n']
        
        self.default_none = ['____Fertilizer_applications                                           0\n',
                             '____Fertilization_option                                              0\n']
        
        # 定义输入参数格式和默认值
        self.default_parameters = {1: {'Fertilizing_month': 1,
                                        'Fertilizing_day': 1,
                                        'Fertilizing_method': 0,
                                        'Fertilizing_depth': 0,
                                        'Nitrate': 0,
                                        'Ammonium_bicarbonate': 0,
                                        'Urea': 1,
                                        'Anhydrous_ammonia': 1,
                                        'Ammonium': 0,
                                        'Sulphate': 0,
                                        'Phosphate': 0,
                                        'Slow_release_rate': 1,
                                        'Nitrification_inhibitor_efficiency': 1,
                                        'Nitrification_inhibitor_duration': 0,
                                        'Urease_inhibitor_efficiency': 0,
                                        'Urease_inhibitor_duration': 0}}
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 进行参数替换的操作函数
    def process_fertilization(self, mode, parameter_dict=None):
        # 判断是那种施肥模式，分别进行不同的操作
        if mode == 'none':
            return self.default_none
        if mode == 'manual':
            return self.process_manual_fertilization(parameter_dict)
        elif mode == 'auto':
            return self.process_auto_fertilization()
        elif mode == 'precision':
            return self.process_precision_fertilization()
        elif mode == 'fertig':
            return self.process_fertig_fertilization(parameter_dict)
        else:
            raise ValueError("Invalid fertilization mode")

    # 定义一个手动施肥参数修改函数
    def process_manual_fertilization(self, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a fertilization dictionary for manual mode.")
        modified_manual_fertilization = self.set_parameters(parameter_dict)
        return modified_manual_fertilization
    
    # 定义一个自动施肥参数修改函数
    def process_auto_fertilization(self):
        # Process and modify the auto_fertilization based on the requirements for auto mode
        modified_auto_fertilization = self.auto_fertilization
        return modified_auto_fertilization
    
    # 定义一个精准施肥参数修改函数
    def process_precision_fertilization(self):
        # Process and modify the precision_fertilization based on the requirements for precision mode
        modified_precision_fertilization = self.precision_fertilization
        return modified_precision_fertilization
    
    # 定义一个按照施肥表进行施肥的修改函数
    def process_fertig_fertilization(self, parameter_dict):
        if not parameter_dict:
            raise ValueError("Please provide a valid path for fertig mode.")
        modified_fertig_fertilization = []
        # Process and modify the fertig_fertilization based on the requirements for fertig mode
        for line in self.fertig_fertilization:
            modified_line = line.replace('path', str(parameter_dict.values()))
            modified_fertig_fertilization.append(modified_line)
            
    # 定义一个参数修改函数
    def set_parameters(self, parameter_dict):
        modified_list = []
        times= len(parameter_dict)
        modified_fertilization_application = [line.replace('1', str(times)) for line in self.default_manual_fertilization_application]
        for fertilizer_times, sub_parameters_dict in parameter_dict.items():
            first_string = self.default_manual_fertilization_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(fertilizer_times), first_string, count=1)
            modified_table = self.modify(self.default_manual_fertilization_informations[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        modified = modified_fertilization_application + modified_list
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义一个子参数修改的函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_table.append(modified_line)
        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在施肥模块中，我们定义了默认的施肥数据的格式，定义了一个函数 `set_parameters` 可以修改默认参数的值，通过传入参数字典列表，可对相应的施肥参数进行修改，得到新的施肥文件。
#
# 注意：
#
# （1）Fertilizing_method：0-surface，1-injection；
# （2）Fertilizing_depth 单位：cm；
# （3）Phosphate 单位 kg P/ha，其他肥料单位也是以纯元素含量为单位，kg/ha；

# %%
# 实例化一个手动施肥
fertilizer_modifier = DNDCFertilizer()

# 查看参数
print(fertilizer_modifier.get_default_parameters())

parameter_dict = {1: {'Fertilizing_month': 4, 'Fertilizing_day': 1, 'Fertilizing_method': 1, 'Fertilizing_depth': 5, 'Urea': 90, 'Phosphate': 50, },
                  2: {'Fertilizing_month': 4, 'Fertilizing_day': 10, 'Fertilizing_method': 0, 'Fertilizing_depth': 0.2, 'Urea': 60},
                  3: {'Fertilizing_month': 6, 'Fertilizing_day': 1, 'Fertilizing_method': 0, 'Fertilizing_depth': 0.2, 'Urea': 60}
                 }
modifier_fertilizer = fertilizer_modifier.process_fertilization('manual', parameter_dict)
modifier_fertilizer
# Out:
# {1: {'Fertilizing_month': 1, 'Fertilizing_day': 1, 'Fertilizing_method': 0, 'Fertilizing_depth': 0, 'Nitrate': 0, 'Ammonium_bicarbonate': 0, 'Urea': 1, 'Anhydrous_ammonia': 1, 'Ammonium': 0, 'Sulphate': 0, 'Phosphate': 0, 'Slow_release_rate': 1, 'Nitrification_inhibitor_efficiency': 1, 'Nitrification_inhibitor_duration': 0, 'Urease_inhibitor_efficiency': 0, 'Urease_inhibitor_duration': 0}}
# ['____Fertilizer_applications                                            3\n',
#  '______Fertilizing#                                                     1\n',
#  '______Fertilizing_month                                                4\n',
#  '______Fertilizing_day                                                  1\n',
#  '______Fertilizing_method                                               1\n',
#  '______Fertilizing_depth                                                5\n',
#  '______Nitrate                                                     0.0000\n',
#  '______Ammonium_bicarbonate                                        0.0000\n',
#  '______Urea                                                            90\n',
#  '______Anhydrous_ammonia                                           0.0000\n',
#  '______Ammonium                                                    0.0000\n',
#  '______Sulphate                                                    0.0000\n',
#  '______Phosphate                                                       50\n',
#  '______Slow_release_rate                                           1.0000\n',
#  '______Nitrification_inhibitor_efficiency                          0.0000\n',
#  '______Nitrification_inhibitor_duration                            0.0000\n',
#  '______Urease_inhibitor_efficiency                                 0.0000\n',
#  '______Urease_inhibitor_duration                                   0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______Fertilizing#                                                     2\n',
#  '______Fertilizing_month                                                4\n',
#  '______Fertilizing_day                                                 10\n',
#  '______Fertilizing_method                                               0\n',
#  '______Fertilizing_depth                                              0.2\n',
#  '______Nitrate                                                     0.0000\n',
#  '______Ammonium_bicarbonate                                        0.0000\n',
#  '______Urea                                                            60\n',
#  '______Anhydrous_ammonia                                           0.0000\n',
#  '______Ammonium                                                    0.0000\n',
#  '______Sulphate                                                    0.0000\n',
#  '______Phosphate                                                   0.0000\n',
#  '______Slow_release_rate                                           1.0000\n',
#  '______Nitrification_inhibitor_efficiency                          0.0000\n',
#  '______Nitrification_inhibitor_duration                            0.0000\n',
#  '______Urease_inhibitor_efficiency                                 0.0000\n',
#  '______Urease_inhibitor_duration                                   0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______Fertilizing#                                                     3\n',
#  '______Fertilizing_month                                                6\n',
#  '______Fertilizing_day                                                  1\n',
#  '______Fertilizing_method                                               0\n',
#  '______Fertilizing_depth                                              0.2\n',
#  '______Nitrate                                                     0.0000\n',
#  '______Ammonium_bicarbonate                                        0.0000\n',
#  '______Urea                                                            60\n',
#  '______Anhydrous_ammonia                                           0.0000\n',
#  '______Ammonium                                                    0.0000\n',
#  '______Sulphate                                                    0.0000\n',
#  '______Phosphate                                                   0.0000\n',
#  '______Slow_release_rate                                           1.0000\n',
#  '______Nitrification_inhibitor_efficiency                          0.0000\n',
#  '______Nitrification_inhibitor_duration                            0.0000\n',
#  '______Urease_inhibitor_efficiency                                 0.0000\n',
#  '______Urease_inhibitor_duration                                   0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n']

# %%
# 实例化一个不施肥
fertilizer_modifier = DNDCFertilizer()

modifier_fertilizer = fertilizer_modifier.process_fertilization('none')
modifier_fertilizer
# Out:
# ['____Fertilizer_applications                                           0\n',
#  '____Fertilization_option                                              0\n']

# %% [markdown]
# #### 4.4 有机物料添加
# 有机物料的添加 dnd 文件格式主要如下：
#
# ![image.png](attachment:image.png)

# %%
import re

class DNDCManure:
    # 定义有机肥文件格式和默认参数
    def __init__(self):
        self.default_manure_applications = ['____Manure_applications                                               1\n']
        self.default_manure_informations = ['______Manuring#                                                       1\n',
                                            '______Manuring_month                                                  1\n',
                                            '______Manuring_day                                                    1\n',
                                            '______Manure_amount                                                   0\n',
                                            '______Manure_C/N                                                13.0000\n',
                                            '______Manure_type                                                     1\n',
                                            '______Manuring_method                                                 0\n',
                                            '______Manure_depth                                               0.0000\n',
                                            '______Manure_OrgN                                                0.0000\n',
                                            '______Manure_NH4                                                 0.0000\n',
                                            '______Manure_NO3                                                 0.0000\n',
                                            '______None                                                            0\n']
        self.without_manure = ['____Manure_applications                                               0\n']
        self.default_parameters = {1: {'Manuring_month': 1,
                                        'Manuring_day': 1,
                                        'Manure_amount': 0,
                                        'Manure_C/N': 0, 
                                        'Manure_type': 0,
                                        'Manuring_method': 0,
                                        'Manure_depth': 0,
                                        'Manure_OrgN': 0,
                                        'Manure_NH4': 0,
                                        'Manure_NO3': 0}}
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 定义有机肥参数修改操作
    def process_manure(self, mode, parameter_dict=None):
        # 判断是否施用有机肥
        if mode == 'none':
            return self.without_manure
        elif mode == 'manure':
            return self.process_manure_fertilization(parameter_dict)
        else:
            raise ValueError("Invalid manure mode")
        
    # 定义有机肥施用参数修改函数
    def process_manure_fertilization(self, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a manure dictionary for manual mode.")
        modified_manure_fertilization = self.set_parameters(parameter_dict)
        return modified_manure_fertilization    
    
    # 定义参数修改函数
    def set_parameters(self, parameter_dict):               
        modified_list = []
        times= len(parameter_dict)
        modified_manure_application = [line.replace('1', str(times)) for line in self.default_manure_applications]
        for manure_times, sub_parameters_dict in parameter_dict.items():
            # 判断是否输入有机肥类型
            if 'Manure_type' not in sub_parameters_dict:
                raise ValueError("Please define 'Manure_type' in the parameter dictionary.")
            # 施用默认的有机肥参数进行映射
            Manure_type = sub_parameters_dict['Manure_type']
            manure_mapping = self.get_manure_cn_ratio(Manure_type)
            for param_name_manure, param_value_manure in manure_mapping.items():
                if param_name_manure not in sub_parameters_dict.keys():
                    sub_parameters_dict[param_name_manure] = param_value_manure
            
            sub_parameters_dict.update(self.get_nutrients_from_manure(sub_parameters_dict))
                
            first_string = self.default_manure_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(manure_times), first_string, count=1)
            modified_table = self.modify(self.default_manure_informations[1:], sub_parameters_dict)
            
            modified_list.extend([result] + modified_table)
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified_list:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义参数修改方法    
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_table.append(modified_line)
        return modified_table
    
    # 定义有机肥CN比映射方法
    def get_manure_cn_ratio(self, Manure_type):
        # Manure mapping table
        manure_mapping = {
            1: {'Manure_C/N': 13},
            2: {'Manure_C/N': 25},
            3: {'Manure_C/N': 70},
            4: {'Manure_C/N': 5},
            5: {'Manure_C/N': 30},
            6: {'Manure_C/N': 2},
            7: {'Manure_C/N': 5},
            8: {'Manure_C/N': 9.5},
            9: {'Manure_C/N': 5.6},
            10: {'Manure_C/N': 4}
        }
        return manure_mapping.get(Manure_type, {})
    
    # 定义有机肥性质映射方法
    def get_nutrients_from_manure(self, sub_parameters_dict):
        # defaut nutrients mapping table
        Manure_amount = sub_parameters_dict['Manure_amount']
        Manure_CN = sub_parameters_dict['Manure_C/N']
        Manure_OrgN = Manure_amount / Manure_CN
        if sub_parameters_dict['Manure_type'] in [2, 3, 6]:
            Manure_NH4 = 0
            Manure_NO3 = 0
        if sub_parameters_dict['Manure_type'] in [5]:
            Manure_NH4 = Manure_OrgN * 0.5
            Manure_NO3 = Manure_NH4
        if sub_parameters_dict['Manure_type'] in [7]:
            Manure_NH4 = Manure_OrgN * 0.5
            Manure_NO3 = Manure_NH4 * 0.4
        if sub_parameters_dict['Manure_type'] in [8]:
            Manure_NH4 = Manure_OrgN * 0.6
            Manure_NO3 = Manure_NH4 * 0.6667
        if sub_parameters_dict['Manure_type'] in [9]:
            Manure_NH4 = Manure_OrgN * 0.2
            Manure_NO3 = Manure_NH4 * 0.5
        if sub_parameters_dict['Manure_type'] in [10]:
            Manure_NH4 = Manure_OrgN * 0.1
            Manure_NO3 = 0
        if sub_parameters_dict['Manure_type'] in [1, 4]:    
            Manure_NH4 = Manure_OrgN * 0.1
            Manure_NO3 = Manure_NH4 * 0.4
        nutrients_mapping = {
            'Manure_OrgN': round(Manure_OrgN, 4),
            'Manure_NH4': round(Manure_NH4, 4),
            'Manure_NO3': round(Manure_NO3, 4)
        }
        return nutrients_mapping
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在有机肥模块中，我们定义了一个函数 `process_manure` 可以修改默认参数的值，通过传入参数字典列表，可对相应的有机肥添加参数进行修改，得到新的有机肥文件。
#
# 注意：
#
# （1）有机肥类型如下：
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
#
# （2）有机肥碳氮比是根据有机肥类型确定的，也可以手动输入设置；
#
# （3）有机肥的施用量 `Manure_amount` 是以碳含量计的，单位为：kg C/ha；
#
# （4）有机肥的有机氮含量是根据碳氮比计算的，无机氮（铵态氮和硝态氮）是由不同系数与有机氮含量计算的，单位为 kg N/ha；
#
# （5）有机肥施用方式主要有：0-Surface spread，1-Incropration，2-Injection；
#
# （6）有机肥施用深度单位为：cm。

# %%
# 实例化一个有机物料添加
manure_modifier = DNDCManure()

# 获取参数
print(manure_modifier.get_default_parameters())

parameter_dict = {1: {'Manuring_month': 4, 'Manuring_day': 1, 'Manure_amount': 13, 'Manure_C/N': 10, 'Manure_type': 1, 
                      'Manuring_method': 1, 'Manure_depth': 5},
                  2: {'Manuring_month': 4, 'Manuring_day': 1, 'Manure_amount': 13, 'Manure_C/N': 10, 'Manure_type': 1, 
                      'Manuring_method': 1, 'Manure_depth': 5}
                 }
modifier_manure = manure_modifier.process_manure('manure', parameter_dict)
modifier_manure
# Out:
# {1: {'Manuring_month': 1, 'Manuring_day': 1, 'Manure_amount': 0, 'Manure_C/N': 0, 'Manure_type': 0, 'Manuring_method': 0, 'Manure_depth': 0, 'Manure_OrgN': 0, 'Manure_NH4': 0, 'Manure_NO3': 0}}
# ['______Manuring#                                                        1\n',
#  '______Manuring_month                                                   4\n',
#  '______Manuring_day                                                     1\n',
#  '______Manure_amount                                                   13\n',
#  '______Manure_C/N                                                      10\n',
#  '______Manure_type                                                      1\n',
#  '______Manuring_method                                                  1\n',
#  '______Manure_depth                                                     5\n',
#  '______Manure_OrgN                                                    1.3\n',
#  '______Manure_NH4                                                    0.13\n',
#  '______Manure_NO3                                                   0.052\n',
#  '______None                                                             0\n',
#  '______Manuring#                                                        2\n',
#  '______Manuring_month                                                   4\n',
#  '______Manuring_day                                                     1\n',
#  '______Manure_amount                                                   13\n',
#  '______Manure_C/N                                                      10\n',
#  '______Manure_type                                                      1\n',
#  '______Manuring_method                                                  1\n',
#  '______Manure_depth                                                     5\n',
#  '______Manure_OrgN                                                    1.3\n',
#  '______Manure_NH4                                                    0.13\n',
#  '______Manure_NO3                                                   0.052\n',
#  '______None                                                             0\n']

# %% [markdown]
# #### 4.5 灌溉模块
# 在 DNDC 模型中，灌溉文件主要有两种方式产生，一种是基于事件，另一种是基于灌溉指数：
# （1）基于灌溉事件
#
# ![image.png](attachment:image.png)
#
# （2）基于灌溉指数
#
# ![image-2.png](attachment:image-2.png)
#
# 与施肥有点类似。

# %%
import re

class DNDCIrrigation:
    # 定义灌溉文件格式和默认参数
    def __init__(self):
        self.default_events_irrigation_application = ['____Irrigation_applications                                           1\n']
        self.default_events_irrigation_informations = ['____Irrigation_control                                                0\n',
                                                        '____Irrigation_index                                             0.0000\n',
                                                        '____Irrigation_method                                                 0\n',
                                                        '______Irrigation#                                                     1\n',
                                                        '______Irri_month                                                      1\n',
                                                        '______Irri_day                                                        1\n',
                                                        '______Water_amount                                              10.0000\n',
                                                        '______Irri_method                                                     0\n',
                                                        '______None                                                            0\n',
                                                        '______None                                                            0\n',
                                                        '______None                                                            0\n',
                                                        '______None                                                            0\n',
                                                        '______None                                                            0\n']
        self.irrigation_index = ['____Irrigation_applications                                           0\n',
                                 '____Irrigation_control                                                1\n',
                                 '____Irrigation_index                                             0.0000\n',
                                 '____Irrigation_method                                                 0\n']
        self.default_none = ['____Irrigation_applications                                           0\n',
                                 '____Irrigation_control                                                0\n',
                                 '____Irrigation_index                                             0.0000\n',
                                 '____Irrigation_method                                                 0\n']
        
        self.default_parameters_index = {1: {'Irrigation_index': 0,
                                             'Irrigation_method': 0}}
        self.default_parameters_events = {1: {'Irri_month': 0,
                                              'Irri_day': 0, 
                                              'Water_amount': 0,
                                              'Irri_method': 0,}}
    # 获取默认参数的函数
    def get_default_parameters(self, mode=None):
        if mode == None:
            raise ValueError('Please input irrigation mode: "index" or "events".')
        elif mode == 'index':
            return self.default_parameters_index
        elif mode == 'events':
            return self.default_parameters_events
        else: 
            raise ValueError('Please input right irrigation mode: "index" or "events".')
    
    # 进行参数替换操作的函数
    def process_irrigation(self, mode, parameter_dict=None):
        if mode == 'none':
            return self.default_none
        if mode == 'events':
            return self.process_events_irrigation(parameter_dict)
        elif mode == 'index':
            return self.process_index_irrigation(parameter_dict)
        else:
            raise ValueError("Invalid irrigation mode")
        
    # 定义根据事灌溉的函数
    def process_events_irrigation(self, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a irrigation events for events irrigation.")
        if not self.is_nested_dict(parameter_dict):
            raise ValueError("In input error, your input a irrigation index for events. Please provide a irrigation events for events irrigation.")        
        modified_events_irrigation = self.set_parameters(parameter_dict)
        return modified_events_irrigation
    
    # 定义根据灌溉指数的函数
    def process_index_irrigation(self, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a irrigation index dictionary for index irrigation.")
        if self.is_nested_dict(parameter_dict):
            raise ValueError("In input error, your input a irrigation events for index. Please provide a irrigation index dictionary for index irrigation.")
        if not (0 <= parameter_dict['Irrigation_index'] <=1):
            raise ValueError("Irrigation index needs to be between 0 and 1 !")
        if parameter_dict['Irrigation_method'] not in [0,1,2,3]:
            raise ValueError("Irrigation method error. 0-Furrow，1-Sprinkler，2-Drip(0cm)，3-Drip(15cm)")
        modified_index_irrigation = self.set_parameters_index_irrigation(parameter_dict)
        return modified_index_irrigation
    
    # 定义参数修改函数
    def set_parameters(self, parameter_dict):
        modified_list = []
        times= len(parameter_dict)
        modified_irrigation_application = [line.replace('1', str(times)) for line in self.default_events_irrigation_application]
        for irrigation_times, sub_parameters_dict in parameter_dict.items():
            if sub_parameters_dict['Irri_method'] not in [0,1,2,3]:
                raise ValueError("Irrigation method error. 0-Furrow，1-Sprinkler，2-Drip(0cm)，3-Drip(15cm)")
            
            first_string = self.default_events_irrigation_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(irrigation_times), first_string, count=1)
            modified_table = self.modify(self.default_events_irrigation_informations[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified_list:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义子参数修改的函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_line_align = self.custom_align(modified_line, 72)
            modified_table.append(modified_line_align)
        return modified_table
    
    # 定义基于灌溉指数的参数修改函数
    def set_parameters_index_irrigation(self, parameter_dict):
        modified_table = []
        for i in range(len(self.irrigation_index)):
            modified_line = self.irrigation_index[i]
            
            for parameter_name, new_value in parameter_dict.items():
                pattern = re.compile(f'(____{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))  
            modified_line_align = self.custom_align(modified_line, 72)
            modified_table.append(modified_line_align)
        return modified_table
    
    # 定义判断函数
    def is_nested_dict(self, input_dict):
        if isinstance(input_dict, dict):
            for value in input_dict.values():
                if isinstance(value, dict):
                    return True
        return False
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在灌溉模块中，我们定义了一个函数 `process_irrigation` 可以修改默认参数的值，通过传入参数字典列表，可对相应的灌溉参数进行修改，得到新的灌溉文件。
#
# 注意：
#
# （1）灌溉有两种模式：events 和 index，需要定义是那种模式；
#
# （2）两种模式的字典传入格式不一样，需要注意；
#
# （3）灌溉方法有四种：0-Furrow，1-Sprinkler，2-Drip(0cm)，3-Drip(15cm)；
#
# （4）灌溉量单位为：cm。

# %%
# 实例化一个灌溉，基于灌溉指数
irrigation_modifier = DNDCIrrigation()

# 查看参数
print(irrigation_modifier.get_default_parameters('index'))

parameter_dict = {'Irrigation_index': 1, 'Irrigation_method': 3}
modifier_irrigation = irrigation_modifier.process_irrigation('index', parameter_dict)
modifier_irrigation
# Out:
# {1: {'Irrigation_index': 0, 'Irrigation_method': 0}}
# ['____Irrigation_applications                                            0\n',
#  '____Irrigation_control                                                 1\n',
#  '____Irrigation_index                                                   1\n',
#  '____Irrigation_method                                                  3\n']

# %%
# 实例化一个灌溉，基于灌溉事件
irrigation_modifier = DNDCIrrigation()

# 查看参数
print(irrigation_modifier.get_default_parameters('events'))

parameter_dict = {1: {'Irri_month': 4, 'Irri_day': 1, 'Water_amount': 10, 'Irri_method': 0},
                  2: {'Irri_month': 5, 'Irri_day': 1, 'Water_amount': 5, 'Irri_method': 3},
                  3: {'Irri_month': 6, 'Irri_day': 1, 'Water_amount': 5, 'Irri_method': 2,
                  4: {'Irri_month': 7, 'Irri_day': 1, 'Water_amount': 5, 'Irri_method': 1},}
                  }
modifier_irrigation = irrigation_modifier.process_irrigation('events', parameter_dict)
modifier_irrigation
# Out:
# {1: {'Irri_month': 0, 'Irri_day': 0, 'Water_amount': 0, 'Irri_method': 0}}
# ['____Irrigation_control                                                 1\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '______Irrigation#                                                      1\n',
#  '______Irri_month                                                       4\n',
#  '______Irri_day                                                         1\n',
#  '______Water_amount                                                    10\n',
#  '______Irri_method                                                      0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '____Irrigation_control                                                 2\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '______Irrigation#                                                      1\n',
#  '______Irri_month                                                       5\n',
#  '______Irri_day                                                         1\n',
#  '______Water_amount                                                     5\n',
#  '______Irri_method                                                      3\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '____Irrigation_control                                                 3\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '______Irrigation#                                                      1\n',
#  '______Irri_month                                                       6\n',
#  '______Irri_day                                                         1\n',
#  '______Water_amount                                                     5\n',
#  '______Irri_method                                                      2\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n']

# %% [markdown]
# #### 4.6 淹水模块
# 淹水模块有四种类型：
#
# （1）按计划淹水：
#
# ![image.png](attachment:image.png)
#
# （2）雨养
#
# ![image-2.png](attachment:image-2.png)
#
# （3）根据观察数据
#
# ![image-3.png](attachment:image-3.png)
#
# （4）根据经验参数
#
# ![image-4.png](attachment:image-4.png)

# %%
import re

class DNDCFlooding:
    # 定义默认格式
    def __init__(self):
        self.default_flooding_application = ['____Flood_applications                                                0\n',
                                                '____Water_control                                                     0\n',
                                                '____Flood_water_N                                                0.0000\n',
                                                '____Leak_rate                                                    0.0000\n',
                                                '____Water_gather_index                                           1.0000\n',
                                                '____Watertable_file                                                None\n',
                                                '____Empirical_para_1                                             0.0000\n',
                                                '____Empirical_para_2                                             0.0000\n',
                                                '____Empirical_para_3                                             0.0000\n',
                                                '____Empirical_para_4                                             0.0000\n',
                                                '____Empirical_para_5                                             0.0000\n',
                                                '____Empirical_para_6                                             0.0000\n']
        
        self.default_flooding_informations = ['______Flooding#                                                       1\n',
                                                '______Start_month                                                     1\n',
                                                '______Start_day                                                       1\n',
                                                '______End_month                                                       1\n',
                                                '______End_day                                                         1\n',
                                                '______Water_N                                                    0.0000\n',
                                                '______Alter_wet_dry                                                   0\n',
                                                '______None                                                            0\n',
                                                '______None                                                            0\n',
                                                '______None                                                            0\n',
                                                '______None                                                            0\n',
                                                '______None                                                            0\n']
        # 定义输入参数格式和默认值
        self.default_parameters_scheduled = {1:{'Start_month': 1,
                                                'Start_day': 1,
                                                'End_month': 1,
                                                'End_day': 1, 
                                                'Water_N': 0,
                                                'Alter_wet_dry': 0,
                                                'Flood_water_N': 0,
                                                'Leak_rate': 1}
                                                    }
        self.default_parameters_rainfed = {1: {'Water_gather_index': 1,
                                               'Flood_water_N': 0,
                                               'Leak_rate': 1}
                                                    }
        self.default_parameters_observed = {1: {'Watertable_file': 'path',
                                               'Flood_water_N': 0,
                                               'Leak_rate': 1}
                                                    }
        self.default_parameters_empirical = {1: {'Empirical_para_1': 0,
                                                 'Empirical_para_2': 0,
                                                 'Empirical_para_3': 0,
                                                 'Empirical_para_4': 0,
                                                 'Empirical_para_5': 0,
                                                 'Empirical_para_6': 0,
                                                 'Flood_water_N': 0,
                                                 'Leak_rate': 1}
                                                    }
    # 获取默认参数的函数
    def get_default_parameters(self, mode=None):
        if mode == None:
            raise ValueError('Please input flooding mode: "scheduled", "rainfed", "observed", or "empirical".')
        elif mode == 'scheduled':
            return self.default_parameters_scheduled
        elif mode == 'rainfed':
            return self.default_parameters_rainfed
        elif mode == 'observed':
            return self.default_parameters_observed
        elif mode == 'empirical':
            return self.default_parameters_empirical
        else: 
            raise ValueError('Please input right flooding mode: "scheduled", "rainfed", "observed", or "empirical".')
    
    # 定义储量flooding的函数
    def process_flooding(self, mode, parameter_dict=None):
        if mode == 'none':
            return self.default_flooding_application
        if mode == 'scheduled':
            return self.process_scheduled_flooding(parameter_dict)
        elif mode in ['rainfed', 'observed', 'empirical']:
            return self.process_others_flooding(mode, parameter_dict)
        else:
            raise ValueError("Invalid flooding mode")

    # 定义scheduled_flooding处理函数
    def process_scheduled_flooding(self, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a flooding events for flooding.")
        if not self.is_nested_dict(parameter_dict):
            raise ValueError("In input error. Please provide a flooding events for flooding.")
        
        modified_scheduled_flooding = self.set_parameters(parameter_dict)
        return modified_scheduled_flooding
    
    # 定义其他flooding处理函数
    def process_others_flooding(self, mode, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a flooding dictionary for rainfed flooding.")
        if self.is_nested_dict(parameter_dict):
            raise ValueError("In input error, your input flooding scheduled for rainfed.")
       
        modified_others_flooding = self.set_parameters_others(mode, parameter_dict)
        return modified_others_flooding
    
    # 定义参数修改函数
    def set_parameters(self, parameter_dict):       
        modified_list = []
        times= len(parameter_dict)
        modified_flooding_application = self.default_flooding_application
        flooding_application_first = self.default_flooding_application[0]
        pattern_first = re.compile(r'(\d+\.?\d*)')        
        modified_flooding_application_first = pattern_first.sub(str(times), flooding_application_first)
        modified_flooding_application[0] = modified_flooding_application_first
        
        for flooding_times, sub_parameters_dict in parameter_dict.items():
            if not sub_parameters_dict['Alter_wet_dry'] in [0, 1]:
                raise ValueError("Alter wet dry must be 0 or 1. 0-Continuous flooding (10cm), 1-Alter wet dry (-5~5cm).")
            
            first_string = self.default_flooding_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(flooding_times), first_string, count=1)
            modified_table = self.modify(self.default_flooding_informations[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified_list:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义子参数修改函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_line_align = self.custom_align(modified_line, 72)
            modified_table.append(modified_line_align)
        return modified_table
    
    # 定义其他flooding的参数修改函数
    def set_parameters_others(self, mode, parameter_dict):
        if mode == 'rainfed':
            parameter_dict.update({'Water_control': 1})
        elif mode == 'observed':
            parameter_dict.update({'Water_control': 2})
        elif mode == 'empircal':
            parameter_dict.update({'Water_control': 0})
            
        modified_table = []
        for i in range(len(self.default_flooding_application)):
            modified_line = self.default_flooding_application[i]
            
            for parameter_name, new_value in parameter_dict.items():
                pattern = re.compile(f'(____{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_line_align = self.custom_align(modified_line, 72)
            modified_table.append(modified_line_align)
        return modified_table
    
    # 判断
    def is_nested_dict(self, input_dict):
        if isinstance(input_dict, dict):
            for value in input_dict.values():
                if isinstance(value, dict):
                    return True
        return False
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在淹水模块中，我们定义了一个函数 `process_flooding` 可以修改默认参数的值，通过传入参数字典列表，可对相应的淹水参数进行修改，得到新的淹水文件。
#
# 注意：
#
# （1）淹水有四种模式：scheduled、rainfed、observed、empirical，需要定义是那种模式；
#
# （2）四种模式的字典传入格式不一样，需要注意；
#
# （3）是否干湿交替 `Alter_wet_dry` 只有两种情况 ：0-连续淹水（10cm），1-干湿交替（-5~5cm）；
#
# （4）`Water_N` 的单位为：mg/L；`Leak_rate` 的单位为：mm/day。

# %%
# 实例化一个淹水，基于计划安排
flooding_modifier = DNDCFlooding()

# 查看参数格式
print(flooding_modifier.get_default_parameters('scheduled'))

parameter_dict = {1: {'Start_month': 4, 'Start_day': 1, 'End_month': 5, 'End_day': 1, 'Water_N': 10, 'Alter_wet_dry': 0},
                  2: {'Start_month': 6, 'Start_day': 1, 'End_month': 6, 'End_day': 2, 'Water_N': 10, 'Alter_wet_dry': 1},
                  3: {'Start_month': 8, 'Start_day': 1, 'End_month': 9, 'End_day': 1, 'Water_N': 10, 'Alter_wet_dry': 0}}

modifier_flooding= flooding_modifier.process_flooding('scheduled', parameter_dict)
modifier_flooding
# Out:
# {1: {'Start_month': 1, 'Start_day': 1, 'End_month': 1, 'End_day': 1, 'Water_N': 0, 'Alter_wet_dry': 0, 'Flood_water_N': 0, 'Leak_rate': 1}}
# ['______Flooding#                                                        1\n',
#  '______Start_month                                                      4\n',
#  '______Start_day                                                        1\n',
#  '______End_month                                                        5\n',
#  '______End_day                                                          1\n',
#  '______Water_N                                                         10\n',
#  '______Alter_wet_dry                                                    0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______Flooding#                                                        2\n',
#  '______Start_month                                                      6\n',
#  '______Start_day                                                        1\n',
#  '______End_month                                                        6\n',
#  '______End_day                                                          2\n',
#  '______Water_N                                                         10\n',
#  '______Alter_wet_dry                                                    1\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______Flooding#                                                        3\n',
#  '______Start_month                                                      8\n',
#  '______Start_day                                                        1\n',
#  '______End_month                                                        9\n',
#  '______End_day                                                          1\n',
#  '______Water_N                                                         10\n',
#  '______Alter_wet_dry                                                    0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n']

# %%
# 实例化一个淹水，基于雨养
flooding_modifier = DNDCFlooding()

# 查看参数格式
print(flooding_modifier.get_default_parameters('rainfed'))

parameter_dict = {'Flood_water_N': 0.5, 'Leak_rate': 1, 'Water_gather_index': 0.5}
modifier_flooding= flooding_modifier.process_flooding('rainfed', parameter_dict)
modifier_flooding
# Out:
# {1: {'Water_gather_index': 1, 'Flood_water_N': 0, 'Leak_rate': 1}}
# ['____Flood_applications                                                 0\n',
#  '____Water_control                                                      1\n',
#  '____Flood_water_N                                                    0.5\n',
#  '____Leak_rate                                                          1\n',
#  '____Water_gather_index                                               0.5\n',
#  '____Watertable_file                                                 None\n',
#  '____Empirical_para_1                                              0.0000\n',
#  '____Empirical_para_2                                              0.0000\n',
#  '____Empirical_para_3                                              0.0000\n',
#  '____Empirical_para_4                                              0.0000\n',
#  '____Empirical_para_5                                              0.0000\n',
#  '____Empirical_para_6                                              0.0000\n']

# %% [markdown]
# #### 4.7 覆膜模块
# 覆膜方式有三种：greenhouse、mulch、none。
#
# （1）greenhouse
#
# ![image.png](attachment:image.png)
#
# （2）mulch
#
# ![image-2.png](attachment:image-2.png)
#
# （3）none
#
# ![image-4.png](attachment:image-4.png)

# %%
import re

class DNDCMulch:
    # 定义默认参数格式
    def __init__(self):
        self.default_mulch_none = ['____Film_applications                                                 0\n',
                                   '____Method                                                            2\n']
        
        self.default_mulch_informations = ['______Filming#                                                        1\n',
                                           '______Start_month                                                     1\n',
                                           '______Start_day                                                       1\n',
                                           '______End_month                                                       1\n',
                                           '______End_day                                                         1\n',
                                           '______Cover_fraction                                             1.0000\n',
                                           '______None                                                            0\n',
                                           '______None                                                            0\n',
                                           '______None                                                            0\n',
                                           '______None                                                            0\n',
                                           '______None                                                            0\n']
        
        self.default_parameters = {1: {'Start_month': 1,
                                       'Start_day': 0,
                                       'End_month': 1,
                                       'End_day': 1,
                                       'Cover_fraction': 1}
                                                    }
    
    # 获取默认参数的函数
    def get_default_parameters(self):
        return self.default_parameters
    
    # 定义覆膜操作
    def process_mulch(self, mode, parameter_dict=None):
        if mode == 'none':
            return self.default_mulch_none
        elif mode in ['greenhouse', 'mulch']:
            return self.process_mulch_others(mode, parameter_dict)
        else:
            raise ValueError("Invalid flooding mode")

    # 定义其他覆膜操作
    def process_mulch_others(self, mode, parameter_dict):
        if parameter_dict is None:
            raise ValueError("Please provide a mulch dictionary for mulching.")
        modified_scheduled_flooding = self.set_parameters(mode, parameter_dict)
        return modified_scheduled_flooding
    
    # 定义参数修改函数
    def set_parameters(self, mode, parameter_dict):       
        modified_list = []
        times= len(parameter_dict)
        modified_mulch_application = self.default_mulch_none
        mulch_application_first = self.default_mulch_none[0]
        pattern_first = re.compile(r'(\d+\.?\d*)')        
        modified_mulch_application_first = pattern_first.sub(str(times),  mulch_application_first)
        modified_mulch_application[0] = modified_mulch_application_first
        
        if mode == 'greenhouse':
            method = 0
        elif mode == 'mulch':
            method = 1
        mulch_application_method = self.default_mulch_none[1]
        pattern_method = re.compile(r'(\d+\.?\d*)')        
        modified_mulch_application_method = pattern_method.sub(str(method),  mulch_application_method)
        modified_mulch_application[1] = modified_mulch_application_method
        
        for mulch_times, sub_parameters_dict in parameter_dict.items():
            if not sub_parameters_dict['Cover_fraction'] in [0, 1]:
                raise ValueError("Alter cover fraction must be 0 or 1.")
            
            first_string = self.default_mulch_informations[0]
            pattern = re.compile(r'(\d+)')
            result = pattern.sub(str(mulch_times), first_string, count=1)
            modified_table = self.modify(self.default_mulch_informations[1:], sub_parameters_dict)
            modified_list.extend([result] + modified_table)
        # 将字符串设置为两端对齐，中间空格填充    
        modified_output = []
        for substr in modified_list:
            modified_output.append(self.custom_align(substr, 72))    
        return modified_output
    
    # 定义子参数修改函数        
    def modify(self, table, sub_parameter_dict):
        modified_table = []
        for i in range(len(table)):
            modified_line = table[i]
            for parameter_name, new_value in sub_parameter_dict.items():
                pattern = re.compile(f'(______{parameter_name}\\s+)([\\d\\.]+)')
                match = pattern.match(modified_line)
                if match:
                    current_value = match.group(2)
                    modified_line = modified_line.replace(current_value, str(new_value))
            modified_table.append(modified_line)
        return modified_table
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在覆膜模块中，我们定义了一个函数 `process_mulch` 可以修改默认参数的值，通过传入参数字典列表，可对相应的覆膜参数进行修改，得到新的覆膜文件。
#
# 注意：
#
# （1）覆膜有三种模式：greenhouse、mulch、none，需要定义是那种模式；
#
# （2）none 模式下无需传入参数；
#
# （3）Cover fraction 为 0-1 之间的值。

# %%
# 实例化一个覆膜
mulch_modifier = DNDCMulch()

# 查看参数
print(mulch_modifier.get_default_parameters())

parameter_dict = {1: {'Start_month': 2, 'Start_day': 1, 'End_month': 3, 'End_day': 1, 'Cover_fraction': 1},
                  2: {'Start_month': 11, 'Start_day': 1, 'End_month': 12, 'End_day': 1, 'Cover_fraction': 1}}
modifier_mulch = mulch_modifier.process_mulch('mulch', parameter_dict)
modifier_mulch
# Out:
# {1: {'Start_month': 1, 'Start_day': 0, 'End_month': 1, 'End_day': 1, 'Cover_fraction': 1}}
# ['______Filming#                                                         1\n',
#  '______Start_month                                                      2\n',
#  '______Start_day                                                        1\n',
#  '______End_month                                                        3\n',
#  '______End_day                                                          1\n',
#  '______Cover_fraction                                                   1\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______Filming#                                                         2\n',
#  '______Start_month                                                     11\n',
#  '______Start_day                                                        1\n',
#  '______End_month                                                       12\n',
#  '______End_day                                                          1\n',
#  '______Cover_fraction                                                   1\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n']

# %%
# 不覆膜的实例化
modifier_mulch = DNDCMulch().process_mulch('none')
modifier_mulch
# Out:
# ['____Film_applications                                                 0\n',
#  '____Method                                                            2\n']

# %% [markdown]
# #### 4.8 放牧和收割模块
# 由于农田不涉及该模块，所以之定义一个输出无放牧和收割模式的文件。

# %%
class DNDCGrazingCut:
    def __init__(self):
        self.default = ['____Grazing_applications                                              0\n',
                        '----------------------------------------\n',
                        '____Cut_applications                                                  0\n']
    def process_grazingcut(self):
        return self.default

# %%
grazingcut = DNDCGrazingCut().process_grazingcut()
grazingcut
# Out:
# ['____Grazing_applications                                              0\n',
#  '----------------------------------------\n',
#  '____Cut_applications                                                  0\n']

# %% [markdown]
# ### 5、多模块的整合
# 当我们获得了多个模块，我们要将其整合成 Cropping 模块。在 dnd 文件中 Cropping 不分的格式如下：
#
# ![image-2.png](attachment:image-2.png)
#
#
# ### 5.1 Cropping模块整合
# 由于 Cropping 模块涉及到的子模块，比较多，这里需要先将 Cropping 模块整合好再进行整体的整合和输出，

# %%
import re

class DNDCCropping:
    def __init__(self):
        self.defaut_crop_data = ['Crop_data\n',
                                '\n',
                                'Cropping_systems                                                      1\n',
                                '\n']
        
        self.default_crop_system = ['__Cropping_system                                                     1\n',
                                    '__Total_years                                                         1\n',
                                    '__Years_of_a_cycle                                                    1\n']
        
        self.default_year = ['\n',
                            '____Year                                                              1\n']
    
    def define_practices(self, total_year, number_cropping_system, last_year_each_system, cycle_year_each_system):
        self.total_year = total_year
        self.number_cropping_system = number_cropping_system
        self.last_year_each_system = last_year_each_system
        self.cycle_year_each_system = cycle_year_each_system
    
    def cropping(self, crop, tillage, fertilzation, manure, irrigation, flooding, mulch, grazingcut):
        crop_data = self.update_cropping_data(self.defaut_crop_data, self.number_cropping_system)
        crop_systems = self.update_cropping_system(self.number_cropping_system, self.last_year_each_system, self.cycle_year_each_system)
        cropping_system = []
        cropping_system_i = []
        interel = ['----------------------------------------\n']
        for i, sub_system in crop_systems.items():
            year = self.cycle_year_each_system[i-1]
            if year == 1:
                year_data = self.default_year
                cropping_system_i = sub_system + year_data + crop[i-1] + interel + tillage[i-1] + interel +\
                    fertilzation[i-1] + interel + manure[i-1] + interel + mulch[i-1] + interel + flooding[i-1] + interel + irrigation[i-1] + interel +  grazingcut[i-1]
            if year != 1:
                for j in range(year):
                    year_data_j = self.update_year_data(j+1)
                    cropping_system_i_j = year_data_j + crop[i-1][j] + interel + tillage[i-1][j] + interel + fertilzation[i-1][j] +\
                        interel + manure[i-1][j] + interel + mulch[i-1][j] + interel + flooding[i-1][j] + interel + irrigation[i-1][j] + interel + grazingcut[i-1][j]
                    cropping_system_i.extend(cropping_system_i_j + ['\n'])
                cropping_system_i = sub_system + cropping_system_i                
            cropping_system.extend(cropping_system_i + ['\n'])
        cropping_list = crop_data + cropping_system
        # 将字符串设置为两端对齐，中间空格填充    
        cropping_output = []
        for substr in cropping_list:
            cropping_output.append(self.custom_align(substr, 72))    
        return cropping_output
    
      
    def update_cropping_data(self, data, number_cropping_system):       
        pattern = re.compile(f'(Cropping_systems\s+)(\d+)')
        updated_data = [pattern.sub(r'\g<1>{}'.format(number_cropping_system), line) for line in data]
        return updated_data
    
    def update_cropping_system(self, number_cropping_system, last_year_each_system, cycle_year_each_system):
        crop_systems = {}
        for i in range(1, number_cropping_system + 1):
            years = last_year_each_system[i - 1]
            years_cycle = cycle_year_each_system[i - 1]
            crop_systems[i] = ['__Cropping_system                                                     {}\n'.format(i),
                               '__Total_years                                                         {}\n'.format(years),
                               '__Years_of_a_cycle                                                    {}\n'.format(years_cycle)]
        return crop_systems
    
    def update_year_data(self, n):
        year_data = ['\n',
                    '____Year                                                              {}\n'.format(n)]
        return year_data
    
    # 定义一个用于字符串两端对齐的函数
    def custom_align(self, input_string, total_width):
        if any(char.isspace() and char != '\n' for char in input_string):
            char1, char2 = input_string.split()
            result = char1.ljust(total_width - len(char2)) + char2.rjust(len(char2)) + '\n'
        else: 
            result = input_string       
        return result

# %% [markdown]
# 在这个模块中，可以通过 `DNDCCropping().define_practices(total_year, number_cropping_system, last_year_each_system, cycle_year_each_system)` 首先定义一个 Cropping practices，这里的 `total_year` 表示总的模拟年限，`number_cropping_system` 表示模拟年限内耕作系统的数量，`last_year_each_system` 表示每个系统持续的时间（一个列表，元素个数与系统数量对应），`ycle_year_each_system` 表示每个耕作系统的循环年限（一个列表，元素个数与系统数量对应）。
# 接下来，以一个20年的模拟，前10年稻-麦轮作，后10年稻-稻轮作，稻-麦轮作循环年为2，稻-稻轮作循环年为1为例：

# %%
cropping = DNDCCropping()
# 首先我们定义一个20年的模拟，前10年稻-麦轮作，后10年稻-稻轮作，稻-麦轮作循环年为2，稻-稻轮作循环年为1
cropping.define_practices(total_year=20, number_cropping_system=2, last_year_each_system=[10, 10], cycle_year_each_system=[2,1])

# %%
# 然后我们定义子模块
# 首先是作物，前十年的作物为水稻、小麦，均在一年中播种；后十年的作物为早稻和晚稻，也是一年中播种
crop_modifier = DNDCCrop()
# 定义稻-麦轮作水稻的参数
parameter_rw_rice = {'Crop_ID': 20, 
                  'Planting_month': 6, 'Planting_day': 1, 'Harvest_month': 10, 'Harvest_day': 20, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3000
                  }
# 定义稻-麦轮作小麦的参数
parameter_rw_wheat = {'Crop_ID': 2, 
                  'Planting_month': 11, 'Planting_day': 1, 'Harvest_month': 5, 'Harvest_day': 1, 'Harvest_year': 2, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 0,
                  'Maximum_yield': 3200
                  }
# 定义稻-稻轮作水稻1的参数
parameter_rr_rice1 = {'Crop_ID': 20, 
                  'Planting_month': 4, 'Planting_day': 1, 'Harvest_month': 7, 'Harvest_day': 1, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3000
                  }
# 定义稻-麦轮作小麦的参数
parameter_rr_rice2 = {'Crop_ID': 2, 
                  'Planting_month': 7, 'Planting_day': 10, 'Harvest_month': 11, 'Harvest_day': 1, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3100
                  }

# 整合成模块可识别格式
parameter_rw = {1: parameter_rw_rice, 2: parameter_rw_wheat}
parameter_rr = {1: parameter_rr_rice1, 2: parameter_rr_rice2}

# 获得crop模块参数，第一个耕作系统循环年限为2年，所以应该传入两年的参数；第二个系统只有一年，只需传入一个参数
crop = [[crop_modifier.set_parameters(parameter_rw), crop_modifier.set_parameters(parameter_rw)], crop_modifier.set_parameters(parameter_rr)]
crop
# Out:
# [[['____Crops                                                              2\n',
#    '______Crop#                                                            1\n',
#    '______Crop_ID                                                         20\n',
#    '______Planting_month                                                   6\n',
#    '______Planting_day                                                     1\n',
#    '______Harvest_month                                                   10\n',
#    '______Harvest_day                                                     20\n',
#    '______Harvest_year                                                     1\n',
#    '______Residue_left_in_field                                            1\n',
#    '______Maximum_yield                                              3377.58\n',
#    '______Leaf_fraction                                                 0.23\n',
#    '______Stem_fraction                                                 0.24\n',
#    '______Root_fraction                                                 0.12\n',
#    '______Grain_fraction                                                0.41\n',
#    '______Leaf_C/N                                                        85\n',
#    '______Stem_C/N                                                        85\n',
#    '______Root_C/N                                                        85\n',
#    '______Grain_C/N                                                       45\n',
#    '______Accumulative_temperature                                    2000.0\n',
#    '______Optimum_temperature                                           25.0\n',
#    '______Water_requirement                                           2000.0\n',
#    '______N_fixation_index                                              1.05\n',
#    '______Vascularity                                                      1\n',
#    '______If_cover_crop                                                    0\n',
#    '______If_perennial_crop                                                0\n',
#    '______If_transplanted                                                  1\n',
#    '______Tree_maturity_age                                  -107374000.0000\n',
#    '______Tree_current_age                                            0.0000\n',
#    '______Tree_max_leaf                                               0.0000\n',
#    '______Tree_min_leaf                                               0.0000\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '\n',
#    '______Crop#                                                            2\n',
#    '______Crop_ID                                                          2\n',
#    '______Planting_month                                                  11\n',
#    '______Planting_day                                                     1\n',
#    '______Harvest_month                                                    5\n',
#    '______Harvest_day                                                      1\n',
#    '______Harvest_year                                                     2\n',
#    '______Residue_left_in_field                                            1\n',
#    '______Maximum_yield                                               3120.1\n',
#    '______Leaf_fraction                                                 0.21\n',
#    '______Stem_fraction                                                 0.21\n',
#    '______Root_fraction                                                 0.17\n',
#    '______Grain_fraction                                                0.41\n',
#    '______Leaf_C/N                                                        95\n',
#    '______Stem_C/N                                                        95\n',
#    '______Root_C/N                                                        95\n',
#    '______Grain_C/N                                                       40\n',
#    '______Accumulative_temperature                                    1300.0\n',
#    '______Optimum_temperature                                           22.0\n',
#    '______Water_requirement                                            200.0\n',
#    '______N_fixation_index                                               1.0\n',
#    '______Vascularity                                                      0\n',
#    '______If_cover_crop                                                    0\n',
#    '______If_perennial_crop                                                0\n',
#    '______If_transplanted                                                  0\n',
#    '______Tree_maturity_age                                  -107374000.0000\n',
#    '______Tree_current_age                                            0.0000\n',
#    '______Tree_max_leaf                                               0.0000\n',
#    '______Tree_min_leaf                                               0.0000\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '\n'],
#   ['____Crops                                                              2\n',
#    '______Crop#                                                            1\n',
#    '______Crop_ID                                                         20\n',
#    '______Planting_month                                                   6\n',
#    '______Planting_day                                                     1\n',
#    '______Harvest_month                                                   10\n',
#    '______Harvest_day                                                     20\n',
#    '______Harvest_year                                                     1\n',
#    '______Residue_left_in_field                                            1\n',
#    '______Maximum_yield                                              3377.58\n',
#    '______Leaf_fraction                                                 0.23\n',
#    '______Stem_fraction                                                 0.24\n',
#    '______Root_fraction                                                 0.12\n',
#    '______Grain_fraction                                                0.41\n',
#    '______Leaf_C/N                                                        85\n',
#    '______Stem_C/N                                                        85\n',
#    '______Root_C/N                                                        85\n',
#    '______Grain_C/N                                                       45\n',
#    '______Accumulative_temperature                                    2000.0\n',
#    '______Optimum_temperature                                           25.0\n',
#    '______Water_requirement                                           2000.0\n',
#    '______N_fixation_index                                              1.05\n',
#    '______Vascularity                                                      1\n',
#    '______If_cover_crop                                                    0\n',
#    '______If_perennial_crop                                                0\n',
#    '______If_transplanted                                                  1\n',
#    '______Tree_maturity_age                                  -107374000.0000\n',
#    '______Tree_current_age                                            0.0000\n',
#    '______Tree_max_leaf                                               0.0000\n',
#    '______Tree_min_leaf                                               0.0000\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '\n',
#    '______Crop#                                                            2\n',
#    '______Crop_ID                                                          2\n',
#    '______Planting_month                                                  11\n',
#    '______Planting_day                                                     1\n',
#    '______Harvest_month                                                    5\n',
#    '______Harvest_day                                                      1\n',
#    '______Harvest_year                                                     2\n',
#    '______Residue_left_in_field                                            1\n',
#    '______Maximum_yield                                               3120.1\n',
#    '______Leaf_fraction                                                 0.21\n',
#    '______Stem_fraction                                                 0.21\n',
#    '______Root_fraction                                                 0.17\n',
#    '______Grain_fraction                                                0.41\n',
#    '______Leaf_C/N                                                        95\n',
#    '______Stem_C/N                                                        95\n',
#    '______Root_C/N                                                        95\n',
#    '______Grain_C/N                                                       40\n',
#    '______Accumulative_temperature                                    1300.0\n',
#    '______Optimum_temperature                                           22.0\n',
#    '______Water_requirement                                            200.0\n',
#    '______N_fixation_index                                               1.0\n',
#    '______Vascularity                                                      0\n',
#    '______If_cover_crop                                                    0\n',
#    '______If_perennial_crop                                                0\n',
#    '______If_transplanted                                                  0\n',
#    '______Tree_maturity_age                                  -107374000.0000\n',
#    '______Tree_current_age                                            0.0000\n',
#    '______Tree_max_leaf                                               0.0000\n',
#    '______Tree_min_leaf                                               0.0000\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '______None                                                             0\n',
#    '\n']],
#  ['____Crops                                                              2\n',
#   '______Crop#                                                            1\n',
#   '______Crop_ID                                                         20\n',
#   '______Planting_month                                                   4\n',
#   '______Planting_day                                                     1\n',
#   '______Harvest_month                                                    7\n',
#   '______Harvest_day                                                      1\n',
#   '______Harvest_year                                                     1\n',
#   '______Residue_left_in_field                                            1\n',
#   '______Maximum_yield                                              3377.58\n',
#   '______Leaf_fraction                                                 0.23\n',
#   '______Stem_fraction                                                 0.24\n',
#   '______Root_fraction                                                 0.12\n',
#   '______Grain_fraction                                                0.41\n',
#   '______Leaf_C/N                                                        85\n',
#   '______Stem_C/N                                                        85\n',
#   '______Root_C/N                                                        85\n',
#   '______Grain_C/N                                                       45\n',
#   '______Accumulative_temperature                                    2000.0\n',
#   '______Optimum_temperature                                           25.0\n',
#   '______Water_requirement                                           2000.0\n',
#   '______N_fixation_index                                              1.05\n',
#   '______Vascularity                                                      1\n',
#   '______If_cover_crop                                                    0\n',
#   '______If_perennial_crop                                                0\n',
#   '______If_transplanted                                                  1\n',
#   '______Tree_maturity_age                                  -107374000.0000\n',
#   '______Tree_current_age                                            0.0000\n',
#   '______Tree_max_leaf                                               0.0000\n',
#   '______Tree_min_leaf                                               0.0000\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '\n',
#   '______Crop#                                                            2\n',
#   '______Crop_ID                                                          2\n',
#   '______Planting_month                                                   7\n',
#   '______Planting_day                                                    10\n',
#   '______Harvest_month                                                   11\n',
#   '______Harvest_day                                                      1\n',
#   '______Harvest_year                                                     1\n',
#   '______Residue_left_in_field                                            1\n',
#   '______Maximum_yield                                               3120.1\n',
#   '______Leaf_fraction                                                 0.21\n',
#   '______Stem_fraction                                                 0.21\n',
#   '______Root_fraction                                                 0.17\n',
#   '______Grain_fraction                                                0.41\n',
#   '______Leaf_C/N                                                        95\n',
#   '______Stem_C/N                                                        95\n',
#   '______Root_C/N                                                        95\n',
#   '______Grain_C/N                                                       40\n',
#   '______Accumulative_temperature                                    1300.0\n',
#   '______Optimum_temperature                                           22.0\n',
#   '______Water_requirement                                            200.0\n',
#   '______N_fixation_index                                               1.0\n',
#   '______Vascularity                                                      0\n',
#   '______If_cover_crop                                                    0\n',
#   '______If_perennial_crop                                                0\n',
#   '______If_transplanted                                                  1\n',
#   '______Tree_maturity_age                                  -107374000.0000\n',
#   '______Tree_current_age                                            0.0000\n',
#   '______Tree_max_leaf                                               0.0000\n',
#   '______Tree_min_leaf                                               0.0000\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '______None                                                             0\n',
#   '\n']]

# %%
# 耕作
tillage_modifier = DNDCTillage()
# 每年耕地两次，两种耕作系统不同
parameter_t1 = {1: {'Till_month': 6, 'Till_day': 1, 'Till_method': 1},
                2: {'Till_month': 11, 'Till_day': 1, 'Till_method': 1}}
parameter_t2 = {1: {'Till_month': 4, 'Till_day': 1, 'Till_method': 1},
                2: {'Till_month': 7, 'Till_day': 10, 'Till_method': 1}}
tillage1 = tillage_modifier.set_parameters(parameter_t1)
tillage2 = tillage_modifier.set_parameters(parameter_t2)
tillage = [[tillage1, tillage1], tillage2]

# 实例化一个手动施肥
f = DNDCFertilizer().process_fertilization('none')
fertilizer = [[f,f],f]

# 实例化一个有机物料添加
m = DNDCManure().process_manure('none')
manure = [[m,m],m]

# 实例化一个灌溉，基于灌溉指数
irrig = DNDCIrrigation().process_irrigation('none')
irrigation = [[irrig,irrig],irrig]

# 实例化一个淹水，基于雨养
flood = DNDCFlooding().process_flooding('none')
flooding = [[flood, flood], flood]

# 不覆膜的实例化
mul = DNDCMulch().process_mulch('none')
mulch = [[mul,mul],mul]

gc = DNDCGrazingCut().process_grazingcut()
grazingcut = [[gc,gc],gc]

# %%
# 最后整合成 cropping 结果
cropping_result = cropping.cropping(crop, tillage, fertilizer, manure, irrigation, flooding, mulch, grazingcut)
cropping_result
# Out:
# ['Crop_data\n',
#  '\n',
#  'Cropping_systems                                                       2\n',
#  '\n',
#  '__Cropping_system                                                      1\n',
#  '__Total_years                                                         10\n',
#  '__Years_of_a_cycle                                                     2\n',
#  '\n',
#  '____Year                                                               1\n',
#  '____Crops                                                              2\n',
#  '______Crop#                                                            1\n',
#  '______Crop_ID                                                         20\n',
#  '______Planting_month                                                   6\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                   10\n',
#  '______Harvest_day                                                     20\n',
#  '______Harvest_year                                                     1\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                              3377.58\n',
#  '______Leaf_fraction                                                 0.23\n',
#  '______Stem_fraction                                                 0.24\n',
#  '______Root_fraction                                                 0.12\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        85\n',
#  '______Stem_C/N                                                        85\n',
#  '______Root_C/N                                                        85\n',
#  '______Grain_C/N                                                       45\n',
#  '______Accumulative_temperature                                    2000.0\n',
#  '______Optimum_temperature                                           25.0\n',
#  '______Water_requirement                                           2000.0\n',
#  '______N_fixation_index                                              1.05\n',
#  '______Vascularity                                                      1\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  1\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '______Crop#                                                            2\n',
#  '______Crop_ID                                                          2\n',
#  '______Planting_month                                                  11\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                    5\n',
#  '______Harvest_day                                                      1\n',
#  '______Harvest_year                                                     2\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                               3120.1\n',
#  '______Leaf_fraction                                                 0.21\n',
#  '______Stem_fraction                                                 0.21\n',
#  '______Root_fraction                                                 0.17\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        95\n',
#  '______Stem_C/N                                                        95\n',
#  '______Root_C/N                                                        95\n',
#  '______Grain_C/N                                                       40\n',
#  '______Accumulative_temperature                                    1300.0\n',
#  '______Optimum_temperature                                           22.0\n',
#  '______Water_requirement                                            200.0\n',
#  '______N_fixation_index                                               1.0\n',
#  '______Vascularity                                                      0\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  0\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '----------------------------------------\n',
#  '____Till_applications                                                  2\n',
#  '______Till#                                                            1\n',
#  '______Till_month                                                       6\n',
#  '______Till_day                                                         1\n',
#  '______Till_method                                                      1\n',
#  '______Till#                                                            2\n',
#  '______Till_month                                                      11\n',
#  '______Till_day                                                         1\n',
#  '______Till_method                                                      1\n',
#  '----------------------------------------\n',
#  '____Fertilizer_applications                                            0\n',
#  '____Fertilization_option                                               0\n',
#  '----------------------------------------\n',
#  '____Manure_applications                                                0\n',
#  '----------------------------------------\n',
#  '____Film_applications                                                  0\n',
#  '____Method                                                             2\n',
#  '----------------------------------------\n',
#  '____Flood_applications                                                 0\n',
#  '____Water_control                                                      0\n',
#  '____Flood_water_N                                                 0.0000\n',
#  '____Leak_rate                                                     0.0000\n',
#  '____Water_gather_index                                            1.0000\n',
#  '____Watertable_file                                                 None\n',
#  '____Empirical_para_1                                              0.0000\n',
#  '____Empirical_para_2                                              0.0000\n',
#  '____Empirical_para_3                                              0.0000\n',
#  '____Empirical_para_4                                              0.0000\n',
#  '____Empirical_para_5                                              0.0000\n',
#  '____Empirical_para_6                                              0.0000\n',
#  '----------------------------------------\n',
#  '____Irrigation_applications                                            0\n',
#  '____Irrigation_control                                                 0\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '----------------------------------------\n',
#  '____Grazing_applications                                               0\n',
#  '----------------------------------------\n',
#  '____Cut_applications                                                   0\n',
#  '\n',
#  '\n',
#  '____Year                                                               2\n',
#  '____Crops                                                              2\n',
#  '______Crop#                                                            1\n',
#  '______Crop_ID                                                         20\n',
#  '______Planting_month                                                   6\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                   10\n',
#  '______Harvest_day                                                     20\n',
#  '______Harvest_year                                                     1\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                              3377.58\n',
#  '______Leaf_fraction                                                 0.23\n',
#  '______Stem_fraction                                                 0.24\n',
#  '______Root_fraction                                                 0.12\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        85\n',
#  '______Stem_C/N                                                        85\n',
#  '______Root_C/N                                                        85\n',
#  '______Grain_C/N                                                       45\n',
#  '______Accumulative_temperature                                    2000.0\n',
#  '______Optimum_temperature                                           25.0\n',
#  '______Water_requirement                                           2000.0\n',
#  '______N_fixation_index                                              1.05\n',
#  '______Vascularity                                                      1\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  1\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '______Crop#                                                            2\n',
#  '______Crop_ID                                                          2\n',
#  '______Planting_month                                                  11\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                    5\n',
#  '______Harvest_day                                                      1\n',
#  '______Harvest_year                                                     2\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                               3120.1\n',
#  '______Leaf_fraction                                                 0.21\n',
#  '______Stem_fraction                                                 0.21\n',
#  '______Root_fraction                                                 0.17\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        95\n',
#  '______Stem_C/N                                                        95\n',
#  '______Root_C/N                                                        95\n',
#  '______Grain_C/N                                                       40\n',
#  '______Accumulative_temperature                                    1300.0\n',
#  '______Optimum_temperature                                           22.0\n',
#  '______Water_requirement                                            200.0\n',
#  '______N_fixation_index                                               1.0\n',
#  '______Vascularity                                                      0\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  0\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '----------------------------------------\n',
#  '____Till_applications                                                  2\n',
#  '______Till#                                                            1\n',
#  '______Till_month                                                       6\n',
#  '______Till_day                                                         1\n',
#  '______Till_method                                                      1\n',
#  '______Till#                                                            2\n',
#  '______Till_month                                                      11\n',
#  '______Till_day                                                         1\n',
#  '______Till_method                                                      1\n',
#  '----------------------------------------\n',
#  '____Fertilizer_applications                                            0\n',
#  '____Fertilization_option                                               0\n',
#  '----------------------------------------\n',
#  '____Manure_applications                                                0\n',
#  '----------------------------------------\n',
#  '____Film_applications                                                  0\n',
#  '____Method                                                             2\n',
#  '----------------------------------------\n',
#  '____Flood_applications                                                 0\n',
#  '____Water_control                                                      0\n',
#  '____Flood_water_N                                                 0.0000\n',
#  '____Leak_rate                                                     0.0000\n',
#  '____Water_gather_index                                            1.0000\n',
#  '____Watertable_file                                                 None\n',
#  '____Empirical_para_1                                              0.0000\n',
#  '____Empirical_para_2                                              0.0000\n',
#  '____Empirical_para_3                                              0.0000\n',
#  '____Empirical_para_4                                              0.0000\n',
#  '____Empirical_para_5                                              0.0000\n',
#  '____Empirical_para_6                                              0.0000\n',
#  '----------------------------------------\n',
#  '____Irrigation_applications                                            0\n',
#  '____Irrigation_control                                                 0\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '----------------------------------------\n',
#  '____Grazing_applications                                               0\n',
#  '----------------------------------------\n',
#  '____Cut_applications                                                   0\n',
#  '\n',
#  '\n',
#  '__Cropping_system                                                      2\n',
#  '__Total_years                                                         10\n',
#  '__Years_of_a_cycle                                                     1\n',
#  '\n',
#  '____Year                                                               1\n',
#  '____Crops                                                              2\n',
#  '______Crop#                                                            1\n',
#  '______Crop_ID                                                         20\n',
#  '______Planting_month                                                   4\n',
#  '______Planting_day                                                     1\n',
#  '______Harvest_month                                                    7\n',
#  '______Harvest_day                                                      1\n',
#  '______Harvest_year                                                     1\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                              3377.58\n',
#  '______Leaf_fraction                                                 0.23\n',
#  '______Stem_fraction                                                 0.24\n',
#  '______Root_fraction                                                 0.12\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        85\n',
#  '______Stem_C/N                                                        85\n',
#  '______Root_C/N                                                        85\n',
#  '______Grain_C/N                                                       45\n',
#  '______Accumulative_temperature                                    2000.0\n',
#  '______Optimum_temperature                                           25.0\n',
#  '______Water_requirement                                           2000.0\n',
#  '______N_fixation_index                                              1.05\n',
#  '______Vascularity                                                      1\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  1\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '______Crop#                                                            2\n',
#  '______Crop_ID                                                          2\n',
#  '______Planting_month                                                   7\n',
#  '______Planting_day                                                    10\n',
#  '______Harvest_month                                                   11\n',
#  '______Harvest_day                                                      1\n',
#  '______Harvest_year                                                     1\n',
#  '______Residue_left_in_field                                            1\n',
#  '______Maximum_yield                                               3120.1\n',
#  '______Leaf_fraction                                                 0.21\n',
#  '______Stem_fraction                                                 0.21\n',
#  '______Root_fraction                                                 0.17\n',
#  '______Grain_fraction                                                0.41\n',
#  '______Leaf_C/N                                                        95\n',
#  '______Stem_C/N                                                        95\n',
#  '______Root_C/N                                                        95\n',
#  '______Grain_C/N                                                       40\n',
#  '______Accumulative_temperature                                    1300.0\n',
#  '______Optimum_temperature                                           22.0\n',
#  '______Water_requirement                                            200.0\n',
#  '______N_fixation_index                                               1.0\n',
#  '______Vascularity                                                      0\n',
#  '______If_cover_crop                                                    0\n',
#  '______If_perennial_crop                                                0\n',
#  '______If_transplanted                                                  1\n',
#  '______Tree_maturity_age                                  -107374000.0000\n',
#  '______Tree_current_age                                            0.0000\n',
#  '______Tree_max_leaf                                               0.0000\n',
#  '______Tree_min_leaf                                               0.0000\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '______None                                                             0\n',
#  '\n',
#  '----------------------------------------\n',
#  '____Till_applications                                                  2\n',
#  '______Till#                                                            1\n',
#  '______Till_month                                                       4\n',
#  '______Till_day                                                         1\n',
#  '______Till_method                                                      1\n',
#  '______Till#                                                            2\n',
#  '______Till_month                                                       7\n',
#  '______Till_day                                                        10\n',
#  '______Till_method                                                      1\n',
#  '----------------------------------------\n',
#  '____Fertilizer_applications                                            0\n',
#  '____Fertilization_option                                               0\n',
#  '----------------------------------------\n',
#  '____Manure_applications                                                0\n',
#  '----------------------------------------\n',
#  '____Film_applications                                                  0\n',
#  '____Method                                                             2\n',
#  '----------------------------------------\n',
#  '____Flood_applications                                                 0\n',
#  '____Water_control                                                      0\n',
#  '____Flood_water_N                                                 0.0000\n',
#  '____Leak_rate                                                     0.0000\n',
#  '____Water_gather_index                                            1.0000\n',
#  '____Watertable_file                                                 None\n',
#  '____Empirical_para_1                                              0.0000\n',
#  '____Empirical_para_2                                              0.0000\n',
#  '____Empirical_para_3                                              0.0000\n',
#  '____Empirical_para_4                                              0.0000\n',
#  '____Empirical_para_5                                              0.0000\n',
#  '____Empirical_para_6                                              0.0000\n',
#  '----------------------------------------\n',
#  '____Irrigation_applications                                            0\n',
#  '____Irrigation_control                                                 0\n',
#  '____Irrigation_index                                              0.0000\n',
#  '____Irrigation_method                                                  0\n',
#  '----------------------------------------\n',
#  '____Grazing_applications                                               0\n',
#  '----------------------------------------\n',
#  '____Cut_applications                                                   0\n',
#  '\n']

# %% [markdown]
# ### 5.2 最后整体模块的整合和输出
# 这里需要将 `site`、`weather`、`soil`、`cropping` 模块的结果进行整合。

# %%
import re
import sys

class DNDCFixer:
    def __init__(self):
        self.title = ['DNDC_Input_Parameters\n']
        self.interel = ['----------------------------------------\n']
        
    # 定义一个将所有参数链接的函数
    def concat(self, site, weather, soil, cropping):
        # 首先判断模拟年限和气候数据能否对应
        simulated_years = self.get_number_from_list(site, '__Simulated_years')
        climate_files = self.get_number_from_list(weather, '__Climate_files')
        climate_file_mode = self.get_number_from_list(weather, '__Climate_file_mode')
        total_system_years = sum(self.get_system_years(cropping))
        if simulated_years != total_system_years:
            raise ValueError('The total simulated years did not match with total years of cropping systems !')
        if simulated_years != climate_files and climate_file_mode == 0:
            raise ImportError('The number of climate files did not match with the total simulated years !')
        if climate_file_mode == 1 and climate_files != 1:
            raise ImportError('The number of climate file must 1 when using 1 year for all year !')
                           
        self.result = self.title + self.interel + site + self.interel + weather + self.interel + soil + self.interel + cropping
    
    def get_number_from_list(self, list, string):
        for line in list:
            # Use a regex pattern to match __Simulated_years followed by digits
            match = re.match(rf'{string}\s+(\d+)', line)
        
            # Check if the match is found
            if match:
                # Extract the numeric value
                simulated_years = int(match.group(1))
        return simulated_years
    
    def get_system_years(self, list):
        total_years_values = []
        # Join the lines into a single string for easier pattern matching
        input_string = ''.join(list)
        # Use a regex pattern to find __Total_years followed by digits
        matches = re.finditer(r'__Total_years\s+(\d+)', input_string)

        # Iterate over matches and extract the numeric values
        for match in matches:
            total_years_values.append(int(match.group(1)))
        return total_years_values
    
    def to_dnd(self, output_file_path):
        output_string = ''.join(self.result)
        with open(output_file_path, 'w') as file:
            file.write(output_string)

# %% [markdown]
# 这里我们举个例子，使用之前构造的 cropping_result ，将其与 site、weather、soil 整合并输出。

# %%
site = DNDCSiteInfo().set_parameters({'Site_name': 'test', 'Simulated_years': 20, 'Latitude': 52.0})
weather = DNDCWeather().set_parameters({'Climate_data_type': 2, 'N_in_rainfall': 3.0000, 'Air_NH3_concentration': 1.2000, 'Climate_file_mode': 1}, ['path1'])
soil = DNDCSoil().set_parameters({'Land_use_ID': 20, 'Soil_texture_ID':10, 'Clay_fraction': 0.02, 'Litter_fraction': 0.02, 'Humads_fraction': 0.05, 'Humus_fraction': 0.93, 'Top_layer_SOC': 0.1})
fixer = DNDCFixer()
fixer.concat(site, weather, soil, cropping_result)
fixer.to_dnd('E:/model_input/zhejiang/test/input_files/python_output1.dnd')

# %% [markdown]
# 这样我们就将所有自定义的 DNDC 模型所需的参数输出为 dnd 格式了。

# %% [markdown]
# # 三、批量处理气象数据
# 对应气象数据，我们可以手动按 DNDC 模型需要的输入参数格式进行准备。但是对于模拟站点比较多的情况，手动准备气候数据比较麻烦；有人也给出了气象数据的批处理方法：https://github.com/Chao-zheng-W/py_ex/tree/main/DNDC。这里是需要得到气象数据的前提下，但是对于没有观测站的地区，获取气象数据比较麻烦。这里我们可以借助 Google Earth Engine （GEE）的 python API 直接从 GEE 数据库中自动获取气象数据，然后再将数据处理成 DNDC 需要的格式并输出。
#
# 我们首先编写一个模块，从 GEE 上获取气象数据。

# %%
import ee
# 初始化 Earth Engine，如果之前已经登录，则无需再次登录
try:
    ee.Initialize()
except Exception as e:
    # 如果未进行身份验证，则进行身份验证
    ee.Authenticate()
    ee.Initialize()

# %%
# GEE获取气候数据
import ee
import pandas as pd
from tqdm import tqdm

class GEEWeatherData:
    def __init__(self):
        # 初始化类属性
        self.site_coordinates = None
        self.start_date = None
        self.end_date = None
        self.dataset = None
        self.select_band_names = None
        self.resolution = None
        self.latitude_column = None
        self.longitude_column = None
        self.site_name_column = None

    def set_site_coordinates(self, site_coordinates, latitude_column='纬度', longitude_column='经度', site_name_column='站点名称'):
        """
        设置站点经纬度坐标
        Args:
            site_coordinates (pd.DataFrame): 包含站点经纬度的 DataFrame，每个站点是一个行，包含经纬度和站点名称列。
            latitude_column (str): 包含纬度信息的列名，默认为 '纬度'。
            longitude_column (str): 包含经度信息的列名，默认为 '经度'。
            site_name_column (str): 包含站点名称信息的列名，默认为 '站点名称'。

        Returns:
            None
        """
        self.site_coordinates = site_coordinates
        self.latitude_column = latitude_column
        self.longitude_column = longitude_column
        self.site_name_column = site_name_column

    def set_time_range(self, start_date, end_date):
        """
        设置时间范围
        Args:
            start_date (str): 开始日期，格式为 'YYYY-MM-DD'
            end_date (str): 结束日期，格式为 'YYYY-MM-DD'

        Returns:
            None
        """
        self.start_date = start_date
        self.end_date = end_date

    def set_dataset(self, dataset, select_band_names):
        """
        设置数据集和波段名称
        Args:
            dataset (str): Earth Engine 数据集的 ID。
            select_band_names (list): 包含要选择的波段名称的列表。

        Returns:
            None
        """
        self.dataset = ee.ImageCollection(dataset)
        self.select_band_names = select_band_names

    def set_resolution(self, resolution):
        """
        设置分辨率
        Args:
            resolution (int): 分辨率参数。

        Returns:
            None
        """
        self.resolution = resolution

    def get_weather_data(self, time_segments=None):
        """
        获取每个站点经纬度下的逐日最高温、最低温、降水量数据
        Returns:
            dict: 包含每个站点数据的字典，键是站点名称，值是包含温度和降水数据的 Pandas DataFrame。
        """
        if any(v is None for v in [self.site_coordinates, self.start_date, self.end_date, self.dataset,
                                   self.select_band_names, self.resolution]):
            raise ValueError("请设置站点坐标、时间范围、数据集、波段名称和分辨率。")
        weather_data_dict = {}
        
        try:
            if isinstance(self.site_coordinates, pd.Series):
                self.site_coordinates = pd.DataFrame(self.site_coordinates).T

            for index, row in tqdm(self.site_coordinates.iterrows(), desc='Processing Sites', total=len(self.site_coordinates)):
                site_name = row[self.site_name_column]
                latitude = row[self.latitude_column]
                longitude = row[self.longitude_column]

                site_point = ee.Geometry.Point(longitude, latitude)
                date_range = ee.DateRange(self.start_date, self.end_date)

                # 获取数据集
                selected_dataset = self.dataset.filterBounds(site_point).filterDate(date_range)

                # 选择感兴趣的数据集属性
                selected_bands = selected_dataset.select(self.select_band_names)

                # 获取数据
                selected_data = selected_bands.getRegion(site_point, self.resolution).getInfo()
                # 将数据转换为 Pandas DataFrame
                data_df = pd.DataFrame(selected_data[1:], columns=selected_data[0])

                # 存储数据到字典
                if site_name not in weather_data_dict:
                    weather_data_dict[site_name] = {'values': data_df}
                else:
                    # 如果站点已存在，将新数据追加到原有数据
                    weather_data_dict[site_name]['values'] = pd.concat([weather_data_dict[site_name]['values'], data_df])

        except ee.EEException as e:
            print(f"Error: {e}")

            if time_segments is not None:
                print("Trying to fetch data in segments...")
                # 如果出现错误且提供了时间段，尝试按时间段获取数据
                weather_data_dict = self.get_weather_data_in_segments(time_segments)
                
        return weather_data_dict
                

    def get_weather_data_in_segments(self, time_segments):
        """
        分时间段获取数据

        Args:
            time_segments (list): 包含时间段的列表，每个时间段是一个包含开始和结束日期的元组 (start_date, end_date)。

        Returns:
            dict: 包含每个站点数据的字典，键是站点名称，值是包含温度和降水数据的 Pandas DataFrame。
        """
        weather_data_dict = {}

        for time_segment in time_segments:
            start_date, end_date = time_segment
            
            for index, row in self.site_coordinates.iterrows():
                site_name = row[self.site_name_column]
                latitude = row[self.latitude_column]
                longitude = row[self.longitude_column]

                site_point = ee.Geometry.Point(longitude, latitude)
                date_range = ee.DateRange(start_date, end_date)

                # 获取数据集
                selected_dataset = self.dataset.filterBounds(site_point).filterDate(date_range)

                # 选择感兴趣的数据集属性
                selected_bands = selected_dataset.select(self.select_band_names)

                try:
                    # 获取数据
                    selected_data = selected_bands.getRegion(site_point, self.resolution).getInfo()
                    # 将数据转换为 Pandas DataFrame
                    data_df = pd.DataFrame(selected_data[1:], columns=selected_data[0])

                    # 存储数据到字典
                    if site_name not in weather_data_dict:
                        weather_data_dict[site_name] = {'values': data_df}
                    else:
                        # 如果站点已存在，将新数据追加到原有数据
                        weather_data_dict[site_name]['values'] = pd.concat([weather_data_dict[site_name]['values'], data_df])

                except ee.EEException as e:
                    print(f"Error for site {site_name}: {e}")

        return weather_data_dict

# %% [markdown]
# 接下来我们可以通过 `GEEWeatherData` 模块从 GEE 平台获取参数。

# %%
# 示例数据框
data = {'站点名称': ['Site1', 'Site2'],
        '纬度': [40.7128, 34.0522],
        '经度': [-74.0060, -118.2437]}
site_coordinates_df = pd.DataFrame(data)

# 创建 GEEWeatherData 类的实例
weather_data = GEEWeatherData()

# 设置站点经纬度坐标
weather_data.set_site_coordinates(site_coordinates_df, latitude_column='纬度', longitude_column='经度', site_name_column='站点名称')

# 设置时间范围
weather_data.set_time_range('2022-01-01', '2022-01-10')

# 设置分辨率
resolution = 500
weather_data.set_resolution(resolution)

# 设置数据集和波段名称（这里使用了一个示例数据集），首先要去 GEE 数据库了解数据集获取字符串，以及数据库的波段名称
custom_dataset = 'ECMWF/ERA5_LAND/DAILY_AGGR'
band_names = ['temperature_2m_min', 'temperature_2m_max', 'temperature_2m', 'total_precipitation_sum']
weather_data.set_dataset(custom_dataset, band_names)

# 获取天气数据
weather_data_dict = weather_data.get_weather_data()
# Out:
# Processing Sites: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]

# %% [markdown]
# 这里假设初始气象数据的格式为：（1）逐日数据；（2）数据有最高温度MaxT、最低温度MinT、降水量Prec；（3）这些数据都分别存放在单独的文件中；（4）每个数据每列代表一个站点；（5）所有年份数据均存放在一个单个文件中。现在要将这些数据按照每个站点（一级目录）、每年（二级目录）存放，数据格式为txt，第一列为day，第二列为MaxT，第三列为MinT，第四列Prec。温度单位为摄氏度，降水单位为mm。

# %%
# 将气候数据输出为符合条件的格式
import os
from datetime import datetime
output_directory = 'E:/model_input/zhejiang/test/Climate'
# 将数据按照每年存储为txt文件
for site_name in weather_data_dict.keys():
    time = weather_data_dict[site_name]['values']['time']
    year=[]
    day_of_year=[]
    for i, t in enumerate(time):
        standard_datetime = datetime.utcfromtimestamp(t / 1000.0)
        year.append(standard_datetime.year)
        day_of_year.append(standard_datetime.timetuple().tm_yday)
        
    temperature_max = weather_data_dict[site_name]['values']['temperature_2m_max']
    maxt = []
    for i, t in enumerate(temperature_max):
        maxt.append(t-273.15)
    
    temperature_min = weather_data_dict[site_name]['values']['temperature_2m_min']
    mint = []
    for i, t in enumerate(temperature_min):
        mint.append(t-273.15)
        
    precipitation = weather_data_dict[site_name]['values']['total_precipitation_sum']
    prec = []
    for i, p in enumerate(precipitation):
        prec.append(p * 10)
        
    climate_data = {
        'year': year,
        'day': day_of_year,
        'MaxT': maxt,
        'MinT': mint,
        'Prec': prec}
    climate_data = pd.DataFrame(climate_data)
    grouped_by_year = climate_data.groupby('year')
    
    # 创建年份文件夹
    site_folder = os.path.join(output_directory, str(site_name))
    os.makedirs(site_folder, exist_ok=True)
    # 遍历每个年份的数据
    for year, group in grouped_by_year:
        selected_columns = ['day', 'MaxT', 'MinT', 'Prec']
        # 输出到文件
        group[selected_columns].to_csv(os.path.join(site_folder, f'{year}.txt'), sep='\t', index=False, header=False)

# %% [markdown]
# ## 附录
# 在实际情况中，我们输入的经纬度可能是 `度分秒` 格式，需要将其转化为 `度` 的格式，这里我们编写了一个转换的方法：

# %%
# 将度分秒格式转化为度格式
import pandas as pd

class DmsToDegreesConverter:
    def __init__(self, data):
        self.df = pd.DataFrame(data)

    def dms_to_degrees(self, row, col_name):
        degrees = float(row[col_name+'_degrees'])
        minutes = float(row[col_name+'_minutes'])
        seconds = float(row[col_name+'_seconds'])

        # 考虑方向
        if row[col_name+'_direction'] in ['S', 'W']:
            degrees *= -1

        return degrees + minutes/60 + seconds/3600

    def convert_dms_to_degrees(self, col_names):
        for col in col_names:
            # 使用正则表达式提取度、分、秒和方向信息
            pattern = r'(\d+)°(\d+)?[′\']?(\d+)?[″\"]?(\w)?'
            dms_data = self.df[col].str.extract(pattern)

            # 将提取的度、分、秒转换为数值型
            self.df[col+'_degrees'] = pd.to_numeric(dms_data[0], errors='coerce')
            self.df[col+'_minutes'] = pd.to_numeric(dms_data[1], errors='coerce').fillna(0)
            self.df[col+'_seconds'] = pd.to_numeric(dms_data[2], errors='coerce').fillna(0)
            self.df[col+'_direction'] = dms_data[3]

            # 应用转换函数
            self.df[col+'_degrees'] = self.df.apply(lambda row: self.dms_to_degrees(row, col), axis=1)

            # 删除不再需要的中间列
            self.df = self.df.drop(columns=[col+'_minutes', col+'_seconds', col+'_direction'])

    def get_converted_dataframe(self):
        return self.df

# %% [markdown]
# # 四、数据处理演示
# ### 4.1 气象数据准备

# %%
# 首先获取站点坐标
import os
import pandas as pd
from pyDNDC import DNDCSiteInfo, DNDCWeather, DNDCSoil, DNDCCropping, DNDCCrop, DNDCTillage, DNDCFertilizer, DNDCManure, \
    DNDCIrrigation, DNDCFlooding, DNDCMulch, DNDCGrazingCut, DNDCFixer, DmsToDegreesConverter, GEEWeatherData
locdir = os.getcwd()
site_path = os.path.join(locdir, 'site.csv')
site = pd.read_csv(site_path, encoding='gbk')
site
# Out:
#   站点名称          经度         纬度
# 0   S1  121°31′44″  28°21′18″
# 1   S2  120°42′12″   30°37′0″
# 2   S3   120°41′6″  30°37′41″
# 3   S4  120°31′16″  30°30′40″
# 4   S5  120°49′14″  30°31′21″

# %%
# 首先将度分秒格式转化为度
converter = DmsToDegreesConverter(site)
converter.convert_dms_to_degrees(['经度', '纬度'])
# 获取转换后的 DataFrame
converted_df = converter.get_converted_dataframe()
converted_df
# Out:
#   站点名称          经度         纬度  经度_degrees  纬度_degrees
# 0   S1  121°31′44″  28°21′18″  121.528889   28.355000
# 1   S2  120°42′12″   30°37′0″  120.703333   30.616667
# 2   S3   120°41′6″  30°37′41″  120.685000   30.628056
# 3   S4  120°31′16″  30°30′40″  120.521111   30.511111
# 4   S5  120°49′14″  30°31′21″  120.820556   30.522500

# %%
# GEE 上获取数据，我们获取一年的气象数据
# 初始化 GEE
import ee
# 初始化 Earth Engine，如果之前已经登录，则无需再次登录
try:
    ee.Initialize()
except Exception as e:
    # 如果未进行身份验证，则进行身份验证
    ee.Authenticate()
    ee.Initialize()
    
# 创建 GEEWeatherData 类的实例
weather_data = GEEWeatherData()

# 设置站点经纬度坐标
weather_data.set_site_coordinates(converted_df, latitude_column='纬度_degrees', longitude_column='经度_degrees', site_name_column='站点名称')

# 设置时间范围
weather_data.set_time_range('2022-01-01', '2023-01-01')

# 设置分辨率
resolution = 500
weather_data.set_resolution(resolution)

# 设置数据集和波段名称（这里使用了一个示例数据集），首先要去 GEE 数据库了解数据集获取字符串，以及数据库的波段名称
custom_dataset = 'ECMWF/ERA5_LAND/DAILY_AGGR'
band_names = ['temperature_2m_min', 'temperature_2m_max', 'temperature_2m', 'total_precipitation_sum']
weather_data.set_dataset(custom_dataset, band_names)

# 获取天气数据
weather_data_dict = weather_data.get_weather_data()
# Out:
# Processing Sites: 100%|██████████| 5/5 [00:11<00:00,  2.38s/it]

# %%
# 然后将数据输出
import os
from datetime import datetime

output_directory = os.path.join(locdir, 'data/climate')

# 将数据按照每年存储为txt文件
for site_name, site_data in weather_data_dict.items():
    # Check for NaN values in relevant columns
    if site_data['values'][['temperature_2m_max', 'temperature_2m_min', 'total_precipitation_sum']].isna().any().any():
        print(f"Skipping site {site_name} due to NaN values.")
        continue

    # Extract data
    time = site_data['values']['time']
    year = [datetime.utcfromtimestamp(t / 1000.0).year for t in time]
    day_of_year = [datetime.utcfromtimestamp(t / 1000.0).timetuple().tm_yday for t in time]

    maxt = [(t - 273.15) for t in site_data['values']['temperature_2m_max']]
    mint = [(t - 273.15) for t in site_data['values']['temperature_2m_min']]
    prec = [(t * 100) for t in site_data['values']['total_precipitation_sum']] #降水的单位由米转化为cm

    # Create DataFrame
    climate_data = pd.DataFrame({'year': year, 'day': day_of_year, 'MaxT': maxt, 'MinT': mint, 'Prec': prec})
    grouped_by_year = climate_data.groupby('year')

    # 创建年份文件夹
    site_folder = os.path.join(output_directory, str(site_name))
    os.makedirs(site_folder, exist_ok=True)

    # 遍历每个年份的数据
    for year, group in grouped_by_year:
        selected_columns = ['day', 'MaxT', 'MinT', 'Prec']
        # 输出到文件
        group[selected_columns].to_csv(os.path.join(site_folder, f'{year}.txt'), sep='\t', index=False, header=False)

# %% [markdown]
# 这样我们就得到了气象数据：
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)  ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 接下来我们准备处理参数：
#
# ### （1）首先我们定义一个耕作系统

# %%
# 首先我们定义一个耕作系统，沿用前面的例子，定义一个20年的模拟，前10年稻-麦轮作，后10年稻-稻轮作，稻-麦轮作循环年为2，稻-稻轮作循环年为1
cropping = DNDCCropping()
cropping.define_practices(total_year=20, number_cropping_system=2, last_year_each_system=[10, 10], cycle_year_each_system=[2,1])

# %% [markdown]
# ### （2）我们定义作物参数

# %%
# 我们定义作物参数，前十年的作物为水稻、小麦，均在一年中播种；后十年的作物为早稻和晚稻，也是一年中播种
crop_modifier = DNDCCrop()
# 定义稻-麦轮作水稻的参数
parameter_rw_rice = {'Crop_ID': 20, 
                  'Planting_month': 6, 'Planting_day': 1, 'Harvest_month': 10, 'Harvest_day': 20, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3000
                  }
# 定义稻-麦轮作小麦的参数
parameter_rw_wheat = {'Crop_ID': 2, 
                  'Planting_month': 11, 'Planting_day': 1, 'Harvest_month': 5, 'Harvest_day': 1, 'Harvest_year': 2, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 0,
                  'Maximum_yield': 3200
                  }
# 定义稻-稻轮作水稻1的参数
parameter_rr_rice1 = {'Crop_ID': 20, 
                  'Planting_month': 4, 'Planting_day': 1, 'Harvest_month': 7, 'Harvest_day': 1, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3000
                  }
# 定义稻-麦轮作小麦的参数
parameter_rr_rice2 = {'Crop_ID': 2, 
                  'Planting_month': 7, 'Planting_day': 10, 'Harvest_month': 11, 'Harvest_day': 1, 'Harvest_year': 1, 
                  'Residue_left_in_field' : 1, 'If_cover_crop': 0, 'If_perennial_crop': 0, 'If_transplanted': 1,
                  'Maximum_yield': 3100
                  }

# 整合成模块可识别格式
parameter_rw = {1: parameter_rw_rice, 2: parameter_rw_wheat}
parameter_rr = {1: parameter_rr_rice1, 2: parameter_rr_rice2}

# 获得crop模块参数，第一个耕作系统循环年限为2年，所以应该传入两年的参数；第二个系统只有一年，只需传入一个参数
crop = [[crop_modifier.set_parameters(parameter_rw), crop_modifier.set_parameters(parameter_rw)], crop_modifier.set_parameters(parameter_rr)]

# %% [markdown]
# ### （3） 我们再定义其他耕作参数

# %%
# 我们再定义其他参数
# 耕作
tillage_modifier = DNDCTillage()
# 每年耕地两次，两种耕作系统不同
parameter_t1 = {1: {'Till_month': 6, 'Till_day': 1, 'Till_method': 1},
                2: {'Till_month': 11, 'Till_day': 1, 'Till_method': 1}}
parameter_t2 = {1: {'Till_month': 4, 'Till_day': 1, 'Till_method': 1},
                2: {'Till_month': 7, 'Till_day': 10, 'Till_method': 1}}
tillage1 = tillage_modifier.set_parameters(parameter_t1)
tillage2 = tillage_modifier.set_parameters(parameter_t2)
tillage = [[tillage1, tillage1], tillage2]

# 实例化一个手动施肥
f = DNDCFertilizer().process_fertilization('none')
fertilizer = [[f,f],f]

# 实例化一个有机物料添加
m = DNDCManure().process_manure('none')
manure = [[m,m],m]

# 实例化一个灌溉，基于灌溉指数
irrig = DNDCIrrigation().process_irrigation('none')
irrigation = [[irrig,irrig],irrig]

# 实例化一个淹水，基于雨养
flood = DNDCFlooding().process_flooding('none')
flooding = [[flood, flood], flood]

# 不覆膜的实例化
mul = DNDCMulch().process_mulch('none')
mulch = [[mul,mul],mul]

# 放牧和收割
gc = DNDCGrazingCut().process_grazingcut()
grazingcut = [[gc,gc],gc]

# %% [markdown]
# ### （4）对Cropping模块进行整合

# %%
# 然后我们整合成 cropping 结果
cropping_result = cropping.cropping(crop, tillage, fertilizer, manure, irrigation, flooding, mulch, grazingcut)

# %% [markdown]
# ### （5）定义 site、weather、soil参数

# %%
# 站点数据，我们假设只对站点S1处理
site = DNDCSiteInfo().set_parameters({'Site_name': 'test', 'Simulated_years': 20, 'Latitude': converted_df.loc[0, '纬度_degrees']})
# 气象数据
climate_path = [r'E:\pyDNDC\data\climate\S1\2022.txt'] # 注意一定要反斜杠
weather = DNDCWeather().set_parameters({'Climate_data_type': 1, 'N_in_rainfall': 3.0000, 'Air_NH3_concentration': 1.2000, 'Climate_file_mode': 1}, climate_path)
# 土壤数据
soil = DNDCSoil().set_parameters({'Land_use_ID': 2, 'Soil_texture_ID':10, 'Clay_fraction': 0.02, 'Litter_fraction': 0.02, 'Humads_fraction': 0.05, 'Humus_fraction': 0.93, 'Top_layer_SOC': 0.1})

# %% [markdown]
# ### （6）将所有数据整合输出

# %%
# 最后我们将数据整合输出
dnd_output_path = os.path.join(locdir, 'data/dnd_files/S1.dnd')
fixer = DNDCFixer()
fixer.concat(site, weather, soil, cropping_result)
fixer.to_dnd(dnd_output_path)

# %% [markdown]
# 我们发现获得了 dnd 的文件
#
# ![image.png](attachment:image.png)
#
# 文件内的参数格式符合DNDC模型的要求
#
# ![image-2.png](attachment:image-2.png)
#
#
# 我们将其输入 DNDC 模型：
#
# ![image-3.png](attachment:image-3.png)
#
# 即可实现模拟：
#
# ![image-4.png](attachment:image-4.png)
#
#
# 这样的好处是以后可以根据不同的站点土壤、气候、作物、耕作信息，对不同站点的数据进行批量化输入。
